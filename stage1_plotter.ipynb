# %% [markdown]
# If we wish to run our analysis only onto a subset of our samples in order to save time, for example, we can do so my specifying the fraction of the samples we would like to perform our analysis on with the ```--change_fraction``` flag with the accompanying floating value representing the fraction of the samples we want to work on.
#
# For example running this cell below would trim our  ```./config/fraction_processor_samples.json``` by approximately ten percent.

# %% [markdown]
# The code above will only less than a second. This will save a new config file ```./config/fraction_processor_samples.json```. Please note that we don't overwrite the original full config file ```./config/fraction_processor_samples.json```. This is so that if you would like to change your fraction value, you can do so quickly, instead of waiting a full minute to redo the whole prestage step.

# %% [markdown]
# # Stage 1 Validation
# Now we validate our stage 1 outputs by plotting validation histograms. Like ```run_prestage.py``` script, we can specify the options of the plots via ```--input_string``` flag, but with different formating, but this time with mostly just boolean values:
#
#
# Ratio_{Y or N}/LogY_{Y or N}/ShowLumi_{Y or N}/Status_{work or prelim}
#
# Where we specify if we want Data/MC ratio plot in the bottom panel on with "Y" to mean yes and "N" to mean no after ```Ratio_```, plot in log scale in the y axis after ```LogY_```, show integrated luminosity value of the run after ```ShowLumi_``` and status of the plot after ```Status_```, where the option is "work" for "Work in Progress", "prelim" for "Preliminary" and empty character ("") for no mention of the status at all.
#
# Ie: Ratio_Y/LogY_Y/ShowLumi_N/Status_work indicates to have Data/MC ratio plot on the bottom, plot in logarithmic scale, don't show the integrated luminosity value, and have "Work in progress" label
#
# next is the ```--load_path``` flag, which should be identical to the path specified in ```--save_path``` flag when running the ```run_stage1.py``` script.
#
# One can also specify the path to where the validation plots will be saved by adding ```--save_path``` flag onto ```run_stage1_validation.py``` script, or just use the default path ```./validation/figs```

# %%
data_l = ['A', 'B', 'C', 'D','E', 'F','H', 'G']
bkg_l = ['DY','TT','ST','VV','EWK']
sig_l = ['ggH', 'VBF']

#----------------------------------------------------
# data_l = ['C']
# bkg_l = ['DY']
# sig_l = []
vars2plot = ['dimuon', 'dijet', 'jet', 'mu'] 
# vars2plot = ['jet', 'mu','dimuon'] 
# vars2plot = ['dijet', 'jet','dimuon', 'mu']
# vars2plot = ['dijet']

# lumi = 137.9

lumi_dict = {
    "2018" : 59.97,
    "2017" : 41.5,
    "2016postVFP": 19.5,
    "2016preVFP": 16.8,
}
status = "Private_Work"
year = "2018"
# year = "2017"
# year = "2016postVFP"
# year = "2016preVFP"
lumi = lumi_dict[year]
region = "signal"
# region = "h_peak"

# %%
fraction = 1.0
fraction_str = str(fraction).replace('.', '_')
# --vbf_filter_study 

# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec10/stage1_output/{year}/"
# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec05_btagSystFixed_JesJerUncOn/stage1_output/{year}/"
# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff/stage1_output/{year}/"
# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/{year}/"

# label = "rereco_yun_Dec05_btagSystFixed_JesJerUncOn"                                        
# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/"


# label = "V2_Dec16"
# label = "V2_Dec18_RERECO_MuIdMuIso"
# label = "V2_Dec18_RERECO_MuIdMuIso_puOn"
# label = "V2_Dec20_RERECO_MuIdMuIsoRoccor"
# label = "V2_Dec21"
# label = "V2_Dec21_HEMVetoOnZptOn"
# label = "V2_Dec22_HEMVetoOnZptOn_RerecoBtagSF_XS_Rereco"
# label = "V2_Dec22_HEMVetoOnZptOn_RerecoBtagSF_XS_Rereco_BtagWPsFixed"
# label = "V2_Dec22_HEMVetoOnZptOn_ULBtagSF_XS_Rereco_BtagWPsFixed"
# label = "V2_Dec22_HEMVetoOnZptOn_RerecoBtagSF_XS_Rereco_BtagWPsFixed_changedCleanJet"
# label = "V2_Jan10_NewZptReWgt"
# label = "V2_Jan10_NewZptReWgt_JecOff"
# label = "V2_Jan11_NewZptReWgt"
# label ="V2_Jan17_JecDefault_valerieZpt"
# label="V2_Jan25_JecOn_valerieZpt"
label="V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix"

load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'dimuon_cos_theta_eta', 'dimuon_phi_eta', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'll_zstar_log_nominal', 'dimuon_ebe_mass_res', 'dimuon_ebe_mass_res_rel', 'dimuon_rapidity', 'jj_mass_nominal', 'jj_pt_nominal', 'jj_dEta_nominal', 'jj_dPhi_nominal', 'zeppenfeld_nominal', 'rpt_nominal', 'pt_centrality_nominal', 'nsoftjets2_nominal', 'htsoft2_nominal', 'nsoftjets5_nominal', 'htsoft5_nominal', 'njets_nominal', 'jet1_pt_nominal', 'jet2_pt_nominal', 'jet1_eta_nominal', 'jet2_eta_nominal', 'jet1_phi_nominal', 'jet2_phi_nominal', 'jet1_qgl_nominal', 'jet2_qgl_nominal', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'jj_mass_nominal_range2']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43133 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██                                          | 1/21 [00:13<04:34, 13.71s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▏                                       | 2/21 [00:23<03:40, 11.59s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_C/*/*.parquet
#  14%|██████▎                                     | 3/21 [00:31<02:54,  9.70s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_D/*/*.parquet
#  19%|████████▍                                   | 4/21 [01:02<05:10, 18.29s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  43%|██████████████████▊                         | 9/21 [01:35<01:54,  9.58s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  52%|██████████████████████▌                    | 11/21 [01:49<01:28,  8.85s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  57%|████████████████████████▌                  | 12/21 [02:05<01:30, 10.03s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  62%|██████████████████████████▌                | 13/21 [02:05<01:05,  8.18s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  67%|████████████████████████████▋              | 14/21 [02:06<00:45,  6.55s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  71%|██████████████████████████████▋            | 15/21 [02:07<00:31,  5.30s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  76%|████████████████████████████████▊          | 16/21 [02:09<00:21,  4.21s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  81%|██████████████████████████████████▊        | 17/21 [02:14<00:18,  4.57s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//zz/*/*.parquet
#  86%|████████████████████████████████████▊      | 18/21 [02:15<00:10,  3.44s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
#  90%|██████████████████████████████████████▉    | 19/21 [02:18<00:06,  3.40s/it]loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//ggh_powhegPS/*/*.parquet
#  95%|████████████████████████████████████████▉  | 20/21 [02:19<00:02,  2.67s/it]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2018/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 21/21 [02:20<00:00,  6.70s/it]
# finished loading parquet files!
#   0%|                                                    | 0/41 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_mass
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_mass
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_mass
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_mass in 41.798 s.
#   2%|█                                           | 1/41 [00:41<27:51, 41.80s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_pt
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_pt
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_pt in 39.029 s.
#   5%|██▏                                         | 2/41 [01:20<26:06, 40.17s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_eta in 40.627 s.
#   7%|███▏                                        | 3/41 [02:01<25:34, 40.38s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_phi
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_phi
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi in 34.268 s.
#  10%|████▎                                       | 4/41 [02:35<23:24, 37.97s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_cs in 28.966 s.
#  12%|█████▎                                      | 5/41 [03:04<20:49, 34.72s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi_cs in 29.347 s.
#  15%|██████▍                                     | 6/41 [03:34<19:11, 32.89s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_eta in 29.906 s.
#  17%|███████▌                                    | 7/41 [04:03<18:05, 31.92s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi_eta in 29.43 s.
#  20%|████████▌                                   | 8/41 [04:33<17:07, 31.13s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/dmitry/another_fork/copperhead_fork2/src/lib/histogram/plotting.py:153: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mmj_min_dPhi_nominal in 29.409 s.
#  22%|█████████▋                                  | 9/41 [05:02<16:18, 30.59s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mmj_min_dEta_nominal in 30.308 s.
#  24%|██████████▍                                | 10/41 [05:33<15:45, 30.50s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10857965
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 1766716
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 21097
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 30736
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 29241
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 90836
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 20032
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 55347
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 105029
# category_selection zz sum : 2310
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 38835
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 611727
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 1266149
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing ll_zstar_log_nominal in 36.075 s.
#  27%|███████████▌                               | 11/41 [06:09<16:06, 32.21s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10537562
# category_selection data_A sum : 182615
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5343701
# category_selection data_B sum : 92307
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5232154
# category_selection data_C sum : 90296
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24238010
# category_selection data_D sum : 417713
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# ...
# category_selection length: 158334
# category_selection st_tw_top sum : 9708
# var: mu2_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# ggH mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 9196
# var: mu2_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# ggH mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 87444
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# ggH mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 18355
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# ggH mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 47143
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# ggH mode!
# category_selection length: 105029
# category_selection zz sum : 1904
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# ggH mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 19105
# var: mu2_phi
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# ggH mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 582506
# var: mu2_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# ggH mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 713155
# var: mu2_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mu2_phi in 25.881 s.
#  98%|█████████████████████████████████████████▉ | 40/41 [16:58<00:25, 25.81s/it]do_logscale: True
# process: data_A
# is_data: True
# ggH mode!
# category_selection length: 10537562
# category_selection data_A sum : 163874
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# ggH mode!
# category_selection length: 5343701
# category_selection data_B sum : 82898
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# ggH mode!
# category_selection length: 5232154
# category_selection data_C sum : 80998
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# ggH mode!
# category_selection length: 24238010
# category_selection data_D sum : 375966
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# ggH mode!
# category_selection length: 30259595
# category_selection dy_M-100To200 sum : 10283705
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# ggH mode!
# category_selection length: 9255956
# category_selection ttjets_dl sum : 261525
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# ggH mode!
# category_selection length: 289579
# category_selection ttjets_sl sum : 5880
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# ggH mode!
# category_selection length: 158334
# category_selection st_tw_top sum : 9708
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# ggH mode!
# category_selection length: 152873
# category_selection st_tw_antitop sum : 9196
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# ggH mode!
# category_selection length: 499631
# category_selection ww_2l2nu sum : 87444
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# ggH mode!
# category_selection length: 420803
# category_selection wz_3lnu sum : 18355
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# ggH mode!
# category_selection length: 2625207
# category_selection wz_2l2q sum : 47143
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# ggH mode!
# category_selection length: 105029
# category_selection zz sum : 1904
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# ggH mode!
# category_selection length: 1418112
# category_selection ewk_lljj_mll50_mjj120 sum : 19105
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# ggH mode!
# category_selection length: 626326
# category_selection ggh_powhegPS sum : 582506
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# ggH mode!
# category_selection length: 1296384
# category_selection vbf_powheg_dipole sum : 713155
# var: jj_mass_nominal_range2
# values is nan: False
# values is none: False
# VBF activated
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing jj_mass_nominal_range2 in 24.558 s.
# 100%|███████████████████████████████████████████| 41/41 [17:23<00:00, 25.44s/it]
# Finished in 1160.657 s.
# 2025-01-30 23:22:50,801 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 461, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 440, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35474 remote=tcp://127.0.0.1:33711>: Stream is closed
# 2025-01-30 23:22:50,801 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 461, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 440, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35484 remote=tcp://127.0.0.1:33711>: Stream is closed
# 2025-01-30 23:22:50,799 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 461, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 440, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35454 remote=tcp://127.0.0.1:33711>: Stream is closed
# 2025-01-30 23:22:50,799 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 461, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 440, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35458 remote=tcp://127.0.0.1:33711>: Stream is closed
# 2025-01-30 23:22:50,798 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 461, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/utils_comm.py", line 440, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:35472 remote=tcp://127.0.0.1:33711>: Stream is closed

# %%
year = "2017"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}  

year = "2016postVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}  

year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'dimuon_cos_theta_eta', 'dimuon_phi_eta', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'll_zstar_log_nominal', 'dimuon_ebe_mass_res', 'dimuon_ebe_mass_res_rel', 'dimuon_rapidity', 'jj_mass_nominal', 'jj_pt_nominal', 'jj_dEta_nominal', 'jj_dPhi_nominal', 'zeppenfeld_nominal', 'rpt_nominal', 'pt_centrality_nominal', 'nsoftjets2_nominal', 'htsoft2_nominal', 'nsoftjets5_nominal', 'htsoft5_nominal', 'njets_nominal', 'jet1_pt_nominal', 'jet2_pt_nominal', 'jet1_eta_nominal', 'jet2_eta_nominal', 'jet1_phi_nominal', 'jet2_phi_nominal', 'jet1_qgl_nominal', 'jet2_qgl_nominal', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'jj_mass_nominal_range2']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46859 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▏                                       | 2/21 [00:05<00:56,  2.96s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_C/*/*.parquet
#  14%|██████▎                                     | 3/21 [00:15<01:41,  5.65s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_D/*/*.parquet
#  19%|████████▍                                   | 4/21 [00:18<01:20,  4.71s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_E/*/*.parquet
#  24%|██████████▍                                 | 5/21 [00:25<01:29,  5.60s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_F/*/*.parquet
#  29%|████████████▌                               | 6/21 [00:36<01:50,  7.39s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  43%|██████████████████▊                         | 9/21 [00:54<01:18,  6.54s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  52%|██████████████████████▌                    | 11/21 [01:02<00:55,  5.55s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  57%|████████████████████████▌                  | 12/21 [01:09<00:53,  5.91s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  62%|██████████████████████████▌                | 13/21 [01:10<00:37,  4.72s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  67%|████████████████████████████▋              | 14/21 [01:10<00:26,  3.72s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  71%|██████████████████████████████▋            | 15/21 [01:11<00:18,  3.03s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  76%|████████████████████████████████▊          | 16/21 [01:12<00:12,  2.51s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  81%|██████████████████████████████████▊        | 17/21 [01:15<00:10,  2.69s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//zz/*/*.parquet
#  86%|████████████████████████████████████▊      | 18/21 [01:16<00:06,  2.08s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
#  90%|██████████████████████████████████████▉    | 19/21 [01:17<00:03,  1.88s/it]loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//ggh_powhegPS/*/*.parquet
#  95%|████████████████████████████████████████▉  | 20/21 [01:19<00:01,  1.68s/it]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan29_JecOn_TrigMatchFixed_2016UlJetIdFix/stage1_output/2017/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 21/21 [01:20<00:00,  3.83s/it]
# finished loading parquet files!
#   0%|                                                    | 0/41 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_mass
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_mass
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_mass
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_mass in 24.488 s.
#   2%|█                                           | 1/41 [00:24<16:19, 24.49s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_pt
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_pt
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_pt in 22.596 s.
#   5%|██▏                                         | 2/41 [00:47<15:11, 23.38s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_eta in 23.359 s.
#   7%|███▏                                        | 3/41 [01:10<14:47, 23.37s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_phi
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_phi
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi in 23.559 s.
#  10%|████▎                                       | 4/41 [01:34<14:27, 23.44s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_cs in 23.481 s.
#  12%|█████▎                                      | 5/41 [01:57<14:04, 23.46s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi_cs in 23.822 s.
#  15%|██████▍                                     | 6/41 [02:21<13:45, 23.58s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_eta in 23.81 s.
#  17%|███████▌                                    | 7/41 [02:45<13:24, 23.66s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi_eta in 23.283 s.
#  20%|████████▌                                   | 8/41 [03:08<12:56, 23.54s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/dmitry/another_fork/copperhead_fork2/src/lib/histogram/plotting.py:153: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mmj_min_dPhi_nominal in 22.965 s.
#  22%|█████████▋                                  | 9/41 [03:31<12:27, 23.36s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mmj_min_dEta_nominal in 21.742 s.
#  24%|██████████▍                                | 10/41 [03:53<11:48, 22.86s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# ...
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: jj_mass_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing jj_mass_nominal in 20.999 s.
#  37%|███████████████▋                           | 15/41 [05:45<09:43, 22.45s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: jj_pt_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing jj_pt_nominal in 20.864 s.
#  39%|████████████████▊                          | 16/41 [06:06<09:09, 21.97s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: jj_dEta_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/dmitry/another_fork/copperhead_fork2/src/lib/histogram/plotting.py:153: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing jj_dEta_nominal in 20.756 s.
#  41%|█████████████████▊                         | 17/41 [06:27<08:38, 21.61s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 6593233
# category_selection ttjets_dl sum : 1278725
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 200398
# category_selection ttjets_sl sum : 15391
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 115811
# category_selection st_tw_top sum : 22614
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 114511
# category_selection st_tw_antitop sum : 22300
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 338788
# category_selection ww_2l2nu sum : 63159
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 429933
# category_selection wz_3lnu sum : 21021
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2603710
# category_selection wz_2l2q sum : 55542
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 78152
# category_selection zz sum : 1708
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# nocat mode!
# category_selection length: 1054219
# category_selection ewk_lljj_mll50_mjj120 sum : 28949
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 619269
# category_selection ggh_powhegPS sum : 604895
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1284273
# category_selection vbf_powheg_dipole sum : 1254485
# var: jj_dPhi_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/dmitry/another_fork/copperhead_fork2/src/lib/histogram/plotting.py:153: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing jj_dPhi_nominal in 21.115 s.
#  44%|██████████████████▉                        | 18/41 [06:48<08:13, 21.46s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 3553102
# category_selection data_B sum : 63621
# var: zeppenfeld_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 7120951
# category_selection data_C sum : 126609
# var: zeppenfeld_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 3164639
# category_selection data_D sum : 56297
# var: zeppenfeld_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# nocat mode!
# category_selection length: 6885737
# category_selection data_E sum : 122781
# var: zeppenfeld_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# nocat mode!
# category_selection length: 9899971
# category_selection data_F sum : 177771
# var: zeppenfeld_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 29687651
# category_selection dy_M-100To200 sum : 10708191

# %%
label="V2_Jan17_JecDefault_valerieZpt"

year = "2018"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}  


year = "2017"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}  

year = "2016postVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}  

year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"

! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} 
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat vbf -reg {region} --label {label}  
! python validation_plotter_unified.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat ggh -reg {region}  --label {label}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'dimuon_cos_theta_eta', 'dimuon_phi_eta', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'll_zstar_log_nominal', 'dimuon_ebe_mass_res', 'dimuon_ebe_mass_res_rel', 'dimuon_rapidity', 'jj_mass_nominal', 'jj_pt_nominal', 'jj_dEta_nominal', 'jj_dPhi_nominal', 'zeppenfeld_nominal', 'rpt_nominal', 'pt_centrality_nominal', 'nsoftjets2_nominal', 'htsoft2_nominal', 'nsoftjets5_nominal', 'htsoft5_nominal', 'njets_nominal', 'jet1_pt_nominal', 'jet2_pt_nominal', 'jet1_eta_nominal', 'jet2_eta_nominal', 'jet1_phi_nominal', 'jet2_phi_nominal', 'jet1_qgl_nominal', 'jet2_qgl_nominal', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35793 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██                                          | 1/21 [00:12<04:09, 12.49s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▏                                       | 2/21 [00:18<02:46,  8.79s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_C/*/*.parquet
#  14%|██████▎                                     | 3/21 [00:24<02:11,  7.31s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_D/*/*.parquet
#  19%|████████▍                                   | 4/21 [00:49<04:07, 14.54s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  43%|██████████████████▊                         | 9/21 [01:20<01:39,  8.28s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
#  48%|████████████████████▍                      | 10/21 [01:20<01:15,  6.86s/it]loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  52%|██████████████████████▌                    | 11/21 [01:34<01:22,  8.24s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  57%|████████████████████████▌                  | 12/21 [01:44<01:18,  8.71s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  62%|██████████████████████████▌                | 13/21 [01:45<00:55,  6.98s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  67%|████████████████████████████▋              | 14/21 [01:46<00:37,  5.38s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  71%|██████████████████████████████▋            | 15/21 [01:47<00:25,  4.21s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  76%|████████████████████████████████▊          | 16/21 [01:48<00:16,  3.38s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  81%|██████████████████████████████████▊        | 17/21 [01:52<00:13,  3.31s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//zz/*/*.parquet
#  86%|████████████████████████████████████▊      | 18/21 [01:52<00:07,  2.48s/it]loading process ewk_lljj_mll105_160_ptj0..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//ewk_lljj_mll105_160_ptj0/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//ewk_lljj_mll105_160_ptj0/*.parquet Not available. Skipping
# loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//ggh_powhegPS/*/*.parquet
#  95%|████████████████████████████████████████▉  | 20/21 [01:53<00:01,  1.64s/it]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan17_JecDefault_valerieZpt/stage1_output/2018/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 21/21 [01:55<00:00,  5.50s/it]
# finished loading parquet files!
#   0%|                                                    | 0/40 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_mass
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_mass
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_mass in 39.215 s.
#   2%|█                                           | 1/40 [00:39<25:29, 39.22s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_pt
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_pt
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_pt in 32.885 s.
#   5%|██▏                                         | 2/40 [01:12<22:28, 35.49s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_eta in 27.024 s.
#   8%|███▎                                        | 3/40 [01:39<19:30, 31.63s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_phi
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi in 26.434 s.
#  10%|████▍                                       | 4/40 [02:05<17:44, 29.58s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_cs in 26.408 s.
#  12%|█████▌                                      | 5/40 [02:31<16:35, 28.43s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi_cs in 26.352 s.
#  15%|██████▌                                     | 6/40 [02:58<15:42, 27.73s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_cos_theta_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_eta in 26.366 s.
#  18%|███████▋                                    | 7/40 [03:24<15:00, 27.28s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: dimuon_phi_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi_eta in 26.745 s.
#  20%|████████▊                                   | 8/40 [03:51<14:27, 27.11s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: mmj_min_dPhi_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/dmitry/another_fork/copperhead_fork2/src/lib/histogram/plotting.py:153: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/root632/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/root632/lib/python3.12/site-packages/hist/intervals.py:70: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mmj_min_dPhi_nominal in 24.091 s.
#  22%|█████████▉                                  | 9/40 [04:15<13:31, 26.17s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: mmj_min_dEta_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mmj_min_dEta_nominal in 24.319 s.
#  25%|██████████▊                                | 10/40 [04:39<12:47, 25.60s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# nocat mode!
# category_selection length: 626222
# category_selection ggh_powhegPS sum : 611632
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# nocat mode!
# category_selection length: 1296046
# category_selection vbf_powheg_dipole sum : 1265845
# var: ll_zstar_log_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing ll_zstar_log_nominal in 23.656 s.
#  28%|███████████▊                               | 11/40 [05:03<12:05, 25.00s/it]do_logscale: True
# process: data_A
# is_data: True
# nocat mode!
# category_selection length: 10512537
# category_selection data_A sum : 182465
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# nocat mode!
# category_selection length: 5335002
# category_selection data_B sum : 92255
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# nocat mode!
# category_selection length: 5223862
# category_selection data_C sum : 90248
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# nocat mode!
# category_selection length: 24202138
# category_selection data_D sum : 417529
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# nocat mode!
# category_selection length: 30248918
# category_selection dy_M-100To200 sum : 10854929
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# nocat mode!
# category_selection length: 9247822
# category_selection ttjets_dl sum : 1765866
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# nocat mode!
# category_selection length: 288968
# category_selection ttjets_sl sum : 21073
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# nocat mode!
# category_selection length: 158213
# category_selection st_tw_top sum : 30720
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# nocat mode!
# category_selection length: 152766
# category_selection st_tw_antitop sum : 29226
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# nocat mode!
# category_selection length: 499204
# category_selection ww_2l2nu sum : 90816
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# nocat mode!
# category_selection length: 416631
# category_selection wz_3lnu sum : 19926
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# nocat mode!
# category_selection length: 2623580
# category_selection wz_2l2q sum : 55316
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# nocat mode!
# category_selection length: 104916
# category_selection zz sum : 2309
# var: dimuon_ebe_mass_res
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# ...
# category_selection data_F sum : 29898
# var: mu1_phi
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# ggH mode!
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 9756826
# var: mu1_phi
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# ggH mode!
# category_selection length: 2332004
# category_selection ttjets_dl sum : 77131
# var: mu1_phi
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# ggH mode!
# category_selection length: 69291
# category_selection ttjets_sl sum : 1603
# var: mu1_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# ggH mode!
# category_selection length: 44998
# category_selection st_tw_top sum : 3031
# var: mu1_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# ggH mode!
# category_selection length: 43296
# category_selection st_tw_antitop sum : 2900
# var: mu1_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# ggH mode!
# category_selection length: 146575
# category_selection ww_2l2nu sum : 25815
# var: mu1_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# ggH mode!
# category_selection length: 405561
# category_selection wz_3lnu sum : 17810
# var: mu1_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# ggH mode!
# category_selection length: 1395464
# category_selection wz_2l2q sum : 25368
# var: mu1_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# ggH mode!
# category_selection length: 36980
# category_selection zz sum : 643
# var: mu1_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# ggH mode!
# category_selection length: 306880
# category_selection ggh_powhegPS sum : 286772
# var: mu1_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# ggH mode!
# category_selection length: 634667
# category_selection vbf_powheg_dipole sum : 347611
# var: mu1_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mu1_phi in 14.514 s.
#  98%|█████████████████████████████████████████▉ | 39/40 [09:14<00:14, 14.33s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# ggH mode!
# category_selection length: 4211943
# category_selection data_B sum : 66359
# var: mu2_phi
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# ggH mode!
# category_selection length: 1843778
# category_selection data_C sum : 29292
# var: mu2_phi
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# ggH mode!
# category_selection length: 3056490
# category_selection data_D sum : 48181
# var: mu2_phi
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# ggH mode!
# category_selection length: 2823161
# category_selection data_E sum : 45451
# var: mu2_phi
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# ggH mode!
# category_selection length: 1869945
# category_selection data_F sum : 29898
# var: mu2_phi
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-100To200
# is_data: False
# ggH mode!
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 9756826
# var: mu2_phi
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# ggH mode!
# category_selection length: 2332004
# category_selection ttjets_dl sum : 77131
# var: mu2_phi
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# ggH mode!
# category_selection length: 69291
# category_selection ttjets_sl sum : 1603
# var: mu2_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# ggH mode!
# category_selection length: 44998
# category_selection st_tw_top sum : 3031
# var: mu2_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# ggH mode!
# category_selection length: 43296
# category_selection st_tw_antitop sum : 2900
# var: mu2_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# ggH mode!
# category_selection length: 146575
# category_selection ww_2l2nu sum : 25815
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# ggH mode!
# category_selection length: 405561
# category_selection wz_3lnu sum : 17810
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# ggH mode!
# category_selection length: 1395464
# category_selection wz_2l2q sum : 25368
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# ggH mode!
# category_selection length: 36980
# category_selection zz sum : 643
# var: mu2_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll105_160_ptj0
# skipping ewk_lljj_mll105_160_ptj0
# process: ggh_powhegPS
# is_data: False
# ggH mode!
# category_selection length: 306880
# category_selection ggh_powhegPS sum : 286772
# var: mu2_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# ggH mode!
# category_selection length: 634667
# category_selection vbf_powheg_dipole sum : 347611
# var: mu2_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mu2_phi in 14.5 s.
# 100%|███████████████████████████████████████████| 40/40 [09:29<00:00, 14.24s/it]
# Finished in 618.737 s.
# 2025-01-26 09:17:43,023 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:45740 remote=tcp://127.0.0.1:40013>: Stream is closed
# 2025-01-26 09:17:43,023 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:45756 remote=tcp://127.0.0.1:40013>: Stream is closed
# 2025-01-26 09:17:43,025 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:45784 remote=tcp://127.0.0.1:40013>: Stream is closed
# 2025-01-26 09:17:43,028 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:45794 remote=tcp://127.0.0.1:40013>: Stream is closed
# 2025-01-26 09:17:43,029 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 452, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/utils_comm.py", line 431, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:45780 remote=tcp://127.0.0.1:40013>: Stream is closed
