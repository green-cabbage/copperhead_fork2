# %%
import dask_awkward as dak
import awkward as ak
from distributed import LocalCluster, Client, progress
import time
import numpy as np
import matplotlib.pyplot as plt
import json
import mplhep as hep
import glob
import pandas as pd

plt.style.use(hep.style.CMS)

client =  Client(n_workers=15,  threads_per_worker=2, processes=True, memory_limit='8 GiB')
# Out:
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44007 instead
#   warnings.warn(
# Task exception was never retrieved
# future: <Task finished name='Task-5055053' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5055031' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054979' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054902' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054826' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054872' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054799' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054781' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054824' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054898' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054762' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054825' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054860' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054770' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054753' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054840' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054880' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054766' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054899' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054877' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054796' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054793' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054740' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054808' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054768' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054761' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054814' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054760' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054861' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054817' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054811' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054869' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054891' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054784' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054787' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054889' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054850' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054721' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054723' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054884' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054843' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054888' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054847' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054771' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054786' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054845' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054752' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054732' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054728' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054734' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054757' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054881' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054879' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054719' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054867' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054865' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054874' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054789' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054885' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054851' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054837' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054727' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054883' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054716' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054798' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054835' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054875' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054730' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054791' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054858' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054807' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054809' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054804' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054714' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054855' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054778' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054819' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054785' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054886' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054878' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054743' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054756' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054776' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054747' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054828' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054868' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5055047' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054795' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054797' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054729' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054741' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054790' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054801' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054794' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054887' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054736' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054738' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054739' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054859' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054779' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054737' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054735' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054733' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054862' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054780' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054783' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054838' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054742' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054769' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054755' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054751' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054749' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# ...
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054897' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054890' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054876' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054864' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054832' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054820' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054812' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054854' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054788' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054745' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054731' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054715' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054758' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054722' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054815' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054836' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054849' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054816' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054895' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054833' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054725' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054853' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054842' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054892' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054782' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054829' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054830' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054841' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054866' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054724' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054848' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054871' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054767' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054818' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054800' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054777' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-5054806' coro=<Client._gather.<locals>.wait() done, defined at /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
training_samples = {
        "background": [ # for some reason, having more than dy causes things to break
            "dy_M-100To200", 
            "ttjets_dl",
            "ttjets_sl",
            "st_tw_top",
            "st_tw_antitop",
            "ww_2l2nu",
            "wz_1l1nu2q",
            "wz_2l2q",
            "wz_3lnu",
            "zz",
            "ewk_lljj_mll50_mjj120",
        ],
        "signal": [
            "ggh_powheg", 
            "vbf_powheg",
    ],
}
MC_groups = {
    "DY" : ["dy_M-100To200"],
    "Top": ["ttjets_dl",
            "ttjets_sl",
            "st_tw_top",
            "st_tw_antitop",],
    "VV": ["ww_2l2nu",
            "wz_1l1nu2q",
            "wz_2l2q",
            "wz_3lnu",
            "zz",],
    "EWK" : ["ewk_lljj_mll50_mjj120"]
}

# %%
start_time = time.time()
cols_of_interest = [
    'dimuon_mass',
]
additional_fields = [
    "wgt_nominal_total",
    "h_sidebands",
    "h_peak",
    "vbf_cut",
    "nBtagLoose",
    "nBtagMedium",
    "mu1_pt",
    "mu2_pt",
    "mu1_pt_roch",
    "mu2_pt_roch",
    "mu1_pt_fsr",
    "mu2_pt_fsr",
    # "mu1_pt_gf",
    # "mu2_pt_gf",
    "mu1_pt_raw",
    "mu1_eta",
    "mu2_eta",
    "mu1_phi",
    "mu2_phi",
    "dimuon_pt",
    "dimuon_eta",
    "dimuon_phi",
    "dimuon_mass",
    "jet1_rapidity",
    "jet2_rapidity",
    "jet1_phi",
    "jet1_pt",
    "jet2_pt",
    "jet2_phi",
    "jet1_eta",
    "jet2_eta",
    "jj_mass",
    "jj_dEta",
    "event"
]
fields2compute = cols_of_interest +  additional_fields
fields2compute = list(set(fields2compute))

# %%
def getHist(events, field2plot, binning):
    weight = ak.fill_none(events.wgt_nominal_total, value=0)
    value = ak.fill_none(events[field2plot], value=-999)
    # use np.isnan to filter away remaining nan values
    nan_filter = ~(np.isnan(weight) | np.isnan(value)) # some nans are not None, apparently
    weight = weight[nan_filter]
    weight = ak.values_astype(weight, np.float64)
    value = value[nan_filter]
    
    print(f"getHist weight sum: {np.sum(weight)}")
    print(f"getHist value sum: {np.sum(value)}")
    print(f"getHist weight: {weight}")
    print(f"getHist value: {value}")
    # print(f"getHist is none weight: {ak.sum(ak.is_none(weight))}")
    # print(f"getHist is none value: {ak.sum(ak.is_none(value))}")
    # weight = weight/ np.sum(weight) # normalize to one
    # print(f"np.sum(weight): {np.sum(weight)}")
    hist, edges = np.histogram(value, bins=binning, weights=weight)
    print(f"getHist hist b4 normalization: {hist}")
    hist = hist / np.sum(hist)
    print(f"np.sum(hist): {np.sum(hist)}")
    return hist, edges

def applyGGH_cut(events):
    btag_cut =ak.fill_none((events.nBtagLoose >= 2), value=False) | ak.fill_none((events.nBtagMedium >= 1), value=False)
    # vbf_cut = ak.fill_none(events.vbf_cut, value=False
    vbf_cut = (events.jj_mass > 400) & (events.jj_dEta > 2.5)
    # vbf_cut = (events.jj_mass > 400) & (events.jj_dEta > 2.5) & (events.jet1_pt > 35) 
    vbf_cut = ak.fill_none(vbf_cut, value=False)
    # region = events.h_sidebands | events.h_peak
    dimuon_mass = events.dimuon_mass
    region = (dimuon_mass >= 110) & (dimuon_mass <= 150.0)
    
    # region = events.h_sidebands 
    ggH_filter = (
        ~vbf_cut & 
        region &
        ~btag_cut # btag cut is for VH and ttH categories
    )
    return events[ggH_filter]


def applyVBF_cut(events):
    btag_cut =ak.fill_none((events.nBtagLoose >= 2), value=False) | ak.fill_none((events.nBtagMedium >= 1), value=False)
    # vbf_cut = ak.fill_none(events.vbf_cut, value=False
    vbf_cut = (events.jj_mass > 400) & (events.jj_dEta > 2.5) & (events.jet1_pt > 35) 
    vbf_cut = ak.fill_none(vbf_cut, value=False)
    # region = events.h_peak 
    # region = events.h_sidebands | events.h_peak
    # region = events.h_sidebands 
    dimuon_mass = events.dimuon_mass
    # region = (dimuon_mass >= 110) & (dimuon_mass <= 150.0)
    region = (dimuon_mass > 115.03) & (dimuon_mass < 135.03)
    # region = ((dimuon_mass > 110) & (dimuon_mass < 115.03)) | ((dimuon_mass > 135.03) & (dimuon_mass < 150))
    VBF_filter = (
        vbf_cut & 
        region &
        ~btag_cut # btag cut is for VH and ttH categories
    )
    trues = ak.ones_like(dimuon_mass, dtype="bool")
    falses = ak.zeros_like(dimuon_mass, dtype="bool")
    events["vbf_filter"] = ak.where(VBF_filter, trues,falses)
    return events[VBF_filter]
    # return events

def calculateEdgeCases(events):
    dimuon_mass = events.dimuon_mass
    within_SR = (dimuon_mass >= 110) & (dimuon_mass <= 150)
    print(f"ak.num(within_SR,axis=0): {ak.num(within_SR,axis=0)}")
    region = events.h_sidebands | events.h_peak
    print(f"ak.num(region,axis=0): {ak.num(region,axis=0)}")
    print(f"ak.sum(region): {ak.sum(region)}")
    test_filter = ~(within_SR & region)
    test_filter = test_filter[within_SR]
    return test_filter

def getDeltaPhi(phi1,phi2):
    phi1 = ak.values_astype(phi1, np.float64)
    phi2 = ak.values_astype(phi2, np.float64)
    # print(f"phi1: {phi1.compute()}")
    dphi = abs(np.mod(phi1 - phi2 + np.pi, 2 * np.pi) - np.pi)
    return dphi

def computeBkgFromParquet(load_path, bkgSample_l, fields2compute):
    zip_l = []
    # fields2compute =  fields2compute +["wgt_nominal_zpt_wgt"]
    for sample in bkgSample_l:
        events = dak.from_parquet(load_path+f"/{sample}/*/*.parquet")
        # print(events.fields)
        # print(events.wgt_nominal_zpt_wgt)
        # events["jj_dRapidity"] = np.abs(events.jet1_rapidity - events.jet2_rapidity)
        # events["mmj1_dRapidity"] = np.abs(events.jet1_rapidity - events.dimuon_rapidity)
        # events["mmj2_dRapidity"] = np.abs(events.jet2_rapidity - events.dimuon_rapidity)
        events["jj_dPhiV2"] = ak.fill_none(getDeltaPhi(events.jet1_phi, events.jet2_phi), value=-1)
        # bool_filter = ak.fill_none((events.mmj1_dEta < events.mmj2_dEta), value=True)
        # events["mmj_min_dEtaV2"] = ak.where(bool_filter, events.mmj1_dEta, events.mmj2_dEta)
        # bool_filter = ak.fill_none((events.mmj1_dPhi < events.mmj2_dPhi), value=True)
        # events["mmj_min_dPhiV2"] = ak.where(bool_filter, events.mmj1_dPhi, events.mmj2_dPhi)
        zip = ak.zip({field: events[field] for field in fields2compute}).compute()
        zip_l.append(zip)
    
    final_zip = ak.concatenate(zip_l)
    # zpt removal test start ------------------------
    # final_zip["wgt_nominal_total"] = final_zip.wgt_nominal_total / final_zip.wgt_nominal_zpt_wgt
    # zpt removal test end ------------------------
    return final_zip

# %%
# """
# similar test, but with VBF
# """
# # normal from_parquet doesn't work, so using convoluted concatenating method
# # year = 2018
# # load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}*/f1_0"
# # load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}preVFP/f1_0"
# # load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}/f1_0"
# # load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}/f1_0"
# # load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/*/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_WgtON_original_AN_BDTV2_Oct18/*/f1_0"


# events_data = dak.from_parquet(f"{load_path}/data_*/*/*.parquet")
# events_data = ak.zip({field: events_data[field] for field in fields2compute}).compute()
# edge_cases = calculateEdgeCases(events_data)
# print(ak.sum(edge_cases))
# print(ak.num(edge_cases, axis=0))
# # events_data = applyVBF_cut(events_data)
# # data_yield = ak.num(events_data.dimuon_mass, axis=0)
# # data_yield

# %%
import dask_awkward as dak
import awkward as ak
from distributed import LocalCluster, Client, progress
import time
import numpy as np
import matplotlib.pyplot as plt
import json
import mplhep as hep
import glob
import pandas as pd

plt.style.use(hep.style.CMS)

client =  Client(n_workers=15,  threads_per_worker=2, processes=True, memory_limit='10 GiB')

# %%
"""
copperheadV1 test
"""
import glob

def applyVBF_cutV1(events):
    btag_cut =ak.fill_none((events.nBtagLoose_nominal >= 2), value=False) | ak.fill_none((events.nBtagMedium_nominal >= 1), value=False)
    # vbf_cut = ak.fill_none((events.jj_mass_nominal > 400), value=False) & ak.fill_none((events.jj_dEta_nominal > 2.5), value=False) & ak.fill_none((events.jet1_pt_nominal > 35), value=False) 
    vbf_cut = ak.fill_none((events.jj_mass_nominal > 400), value=False) & ak.fill_none((events.jj_dEta_nominal > 2.5), value=False)
    # vbf_cut = ak.fill_none(vbf_cut, value=False)
    dimuon_mass = events.dimuon_mass
    # region = (dimuon_mass >= 110) & (dimuon_mass <= 150.0)
    # region = (dimuon_mass > 115.03) & (dimuon_mass < 135.03)
    # region = ((dimuon_mass > 110) & (dimuon_mass < 115.03)) | ((dimuon_mass > 135.03) & (dimuon_mass < 150))

    # region = (events.region == "h-peak") | (events.region == "h-sidebands")
    # region = events.region == "h-sidebands"
    VBF_filter = (
        vbf_cut & 
        ~btag_cut # btag cut is for VH and ttH categories
    )
    trues = ak.ones_like(dimuon_mass, dtype="bool")
    falses = ak.zeros_like(dimuon_mass, dtype="bool")
    events["vbf_filter"] = ak.where(VBF_filter, trues,falses)
    return events[VBF_filter]
    # return events

def applyGGH_cutV1(events):
    btag_cut =ak.fill_none((events.nBtagLoose_nominal >= 2), value=False) | ak.fill_none((events.nBtagMedium_nominal >= 1), value=False)
    vbf_cut = ak.fill_none((events.jj_mass_nominal > 400), value=False) & ak.fill_none((events.jj_dEta_nominal > 2.5), value=False)
    # vbf_cut = (events.jj_mass_nominal > 400) & (events.jj_dEta_nominal > 2.5) & (events.jet1_pt_nominal > 35) 
    # vbf_cut = ak.fill_none(vbf_cut, value=False)
    dimuon_mass = events.dimuon_mass
    ggH_filter = (
        ~vbf_cut & 
        ~btag_cut # btag cut is for VH and ttH categories
    )
    return events[ggH_filter]

def applyttH_hadronic_cut(events):
    btag_cut = ak.fill_none((events.nBtagLoose_nominal >= 2), value=False) | ak.fill_none((events.nBtagMedium_nominal >= 1), value=False)
    ttH_hadronic_filter = (
        btag_cut
    )
    return events[ttH_hadronic_filter]

def filterRegion(events, region="h-peak"):
    dimuon_mass = events.dimuon_mass
    if region =="h-peak":
        region = (dimuon_mass > 115.03) & (dimuon_mass < 135.03)
    elif region =="h-sidebands":
        region = ((dimuon_mass > 110) & (dimuon_mass < 115.03)) | ((dimuon_mass > 135.03) & (dimuon_mass < 150))
    elif region =="signal":
        region = (dimuon_mass >= 110) & (dimuon_mass <= 150.0)

    # mu1_pt = events.mu1_pt
    # mu1ptOfInterest = (mu1_pt > 75) & (mu1_pt < 150.0)
    # events = events[region&mu1ptOfInterest]
    events = events[region]
    return events
    

V1_fields_2compute = [
    "wgt_nominal",
    "nBtagLoose_nominal",
    "nBtagMedium_nominal",
    "mu1_pt",
    "mu2_pt",
    "mu1_eta",
    "mu2_eta",
    "mu1_phi",
    "mu2_phi",
    "dimuon_pt",
    "dimuon_eta",
    "dimuon_phi",
    "dimuon_mass",
    "jet1_phi_nominal",
    "jet1_pt_nominal",
    "jet2_pt_nominal",
    "jet2_phi_nominal",
    "jet1_eta_nominal",
    "jet2_eta_nominal",
    "jj_mass_nominal",
    "jj_dEta_nominal",
    # "region",
    "event",
]
 
# year = "2018"
# year = "2016postVFP"
# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec05_btagSystFixed_JesJerUncOn/stage1_output/{year}/"
# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec10/stage1_output/{year}/"
# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_L1JecOff/stage1_output/{year}/"
# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff/stage1_output/{year}/"
# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/{year}/"
# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec15_JecOff_JesJerUncOn_2016LumiFix/stage1_output/{year}/"

# load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/V2_Dec20_RERECO_MuIdMuIsoRoccor/stage1_output/{year}/f1_0"

# label = "V2_Jan17_JecDefault_valerieZpt"
label = "test_test"
total_integral = 0
for year in ["2018", "2017", "2016postVFP", "2016preVFP"]:
# for year in ["2018", "2017", "2016"]:
    load_path =f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0"
    # load_path =f"//depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec05_btagSystFixed_JesJerUncOn/stage1_output/{year}/"
    filelist = glob.glob(f"{load_path}/data_*")
    print(filelist)
    
    for region in ["signal"]:
        for file in filelist:
            # events_data = dak.from_parquet(f"{file}/*.parquet")
            events_data = dak.from_parquet(f"{file}/*/*.parquet")
            # print(events_data.fields)
            # events_data.fields
            events_data = ak.zip({field: events_data[field] for field in V1_fields_2compute}).compute()
            
            # print(region)
            # raise ValueError
            events_data = filterRegion(events_data, region=region)
            events_data = applyGGH_cutV1(events_data)
            # events_data = applyVBF_cutV1(events_data)
            # events_data = applyttH_hadronic_cut(events_data)
            
            data_yield = ak.num(events_data.dimuon_mass, axis=0)
            # data_yield = ak.num(events_data.dimuon_mass, axis=0).compute()
            # ak.to_dataframe(events_data).to_csv("event_dataC_V1.csv")
            # df = pd.DataFrame({field: ak.fill_none(events_data[field], value=-999.9) for field in events_data.fields})
            # df.to_csv("event_dataC_V1.csv")
            print(f"data_yield for {file}: {data_yield}")
            total_integral += data_yield
print(f"total integral for {region} region : {total_integral}")
# Out:
# ['/depot/cms/users/yun79/hmm/copperheadV1clean/test_test/stage1_output/2018/f1_0/data_C']

# %%
! ls /depot/cms/users/yun79/hmm/copperheadV1clean/
# Out:
# DmitryMaster_JECoff_GeofitFixed_Nov01
# recreate_val_Nov02
# rereco_yun_addJecUnc_Nov5
# rereco_yun_Dec02_puidWgtOn_JecOff
# rereco_yun_Dec02_puidWgtOn_OrigData
# rereco_yun_Dec04NewBtag
# rereco_yun_Dec04_trigmatchOn
# rereco_yun_Dec05_btagSystFixed_JesJerUncOn
# rereco_yun_JecDefaultZptOnJecUncOn_Nov20
# ul_yun_Dec12_JecOff
# ul_yun_Dec12_JecOff_JesJerUncOn
# ul_yun_Dec15_JecOff_JesJerUncOn_2016LumiFix
# V2_Dec16
# V2_Dec18_RERECO_MuIdMuIso
# V2_Dec18_RERECO_MuIdMuIso_puOn
# V2_Dec20_RERECO_MuIdMuIsoRoccor
# V2_Dec21
# V2_Dec21_HEMVetoOnZptOn
# V2_Dec22_HEMVetoOnZptOn_RerecoBtagSF_XS_Rereco
# V2_Dec22_HEMVetoOnZptOn_RerecoBtagSF_XS_Rereco_BtagWPsFixed
# V2_Dec22_HEMVetoOnZptOn_RerecoBtagSF_XS_Rereco_BtagWPsFixed_changedCleanJet
# V2_Dec22_HEMVetoOnZptOn_ULBtagSF_XS_Rereco_BtagWPsFixed
# V2_Jan09_ForZptReWgt
# V2_Jan10_NewZptReWgt
# V2_Jan10_NewZptReWgt_JecOff
# V2_Jan11_ForZptReWgt_JecFixed
# V2_Jan11_NewZptReWgt
# V2_Jan14_JecOn_oldZptWgt
# V2_Jan16_JecDefault_oldZptWgt
# V2_Jan16_JecDefault_plotEveryonesZptWgt
# V2_Jan17_JecDefault_plotEveryonesZptWgt
# V2_Jan17_JecDefault_valerieZpt
# V2_Jan22_JecDefault_plotEveryonesZptWgt

# %%
! ls /depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018/
# Out:
# data_A	       dy_m105_160_vbf_amc	      st_tw_top		 ww_2l2nu
# data_B	       ewk_lljj_mll105_160_ptj0       ttjets_dl		 wz_1l1nu2q
# data_C	       ewk_lljj_mll105_160_py_dipole  ttjets_sl		 wz_2l2q
# data_D	       ggh_powhegPS		      vbf_powheg_dipole  wz_3lnu
# dy_M-100To200  st_tw_antitop		      vbf_powheg_herwig  zz

# %%
# do same for dy sampel

filelist = glob.glob(f"{load_path}/dy_M-100To200")
# print(filelist)

total_integral = 0
for file in filelist:
    events = dak.from_parquet(f"{file}/*.parquet")
    # events = dak.from_parquet(f"{file}/*/*.parquet")
    events = ak.zip({field: events[field] for field in V1_fields_2compute}).compute()
    events = applyVBF_cutV1(events)
    events = filterRegion(events, region="h-sidebands")
    dy_yield = ak.sum(events.wgt_nominal)
    dy_nevents = ak.num(events.wgt_nominal, axis=0)
    # dy_yield = ak.sum(events.wgt_nominal).compute()
    # dy_nevents = ak.num(events.wgt_nominal, axis=0).compute()

    print(f"dy_yield for {file}: {dy_yield}")
    print(f"dy_nevents for {file}: {dy_nevents}")
    total_integral += dy_yield
total_integral
# Out:
# 2025-01-09 19:29:05,996 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,176 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,219 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,231 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,414 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,456 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,557 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,659 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,664 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,770 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:06,907 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,012 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,018 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,163 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,218 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,259 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,345 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,495 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,503 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,580 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,603 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,643 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,809 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,868 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,890 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,890 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,933 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:07,998 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,004 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,085 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,104 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,164 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,331 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,342 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,355 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,361 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,459 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,464 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,592 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,598 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,641 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,723 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,724 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,831 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,860 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,879 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,903 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:08,921 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,049 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,150 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,298 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,343 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,360 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,441 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,458 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,466 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,545 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,547 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,565 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,755 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,804 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,922 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:09,967 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,026 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,104 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,121 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,135 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,190 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,270 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,271 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,405 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,564 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,581 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,589 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,609 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,731 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,754 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,754 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,810 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,879 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,934 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:10,967 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,002 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,026 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,066 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,205 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,208 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,267 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,267 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,325 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,488 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,587 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,590 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,629 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,655 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,701 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,705 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,726 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,969 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:11,987 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,007 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,080 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,081 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,140 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,204 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,255 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,294 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,403 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,450 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,468 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,594 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,657 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,770 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,814 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,829 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,924 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:12,994 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,018 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,029 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,110 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,171 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,178 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,327 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,417 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,551 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,588 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,667 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,817 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,828 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,846 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,944 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,953 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:13,961 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,059 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,228 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,301 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,307 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,402 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,410 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,594 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,658 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,661 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,732 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,746 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:14,977 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,032 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,060 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,070 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,285 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,438 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,478 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,556 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,610 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,657 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,764 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,835 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,877 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:15,896 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,010 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,217 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,330 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,484 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,530 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,533 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,774 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,797 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:16,969 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,019 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,090 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,092 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,135 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,146 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,179 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,253 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,349 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,693 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,771 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,787 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:17,904 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,094 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,364 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,403 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,546 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,574 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,585 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,602 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,668 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,761 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,836 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:18,896 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,198 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,263 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,287 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,439 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,693 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,797 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,815 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:19,901 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,016 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,114 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,144 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,415 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,421 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,439 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,556 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,576 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:20,802 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,028 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,087 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,190 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,405 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,406 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,544 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,798 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:21,929 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,071 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,338 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,348 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,351 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,461 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,467 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,547 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,667 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,682 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:22,982 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-09 19:29:23,201 - distributed.utils_perf - WARNING - full garbage collections took 27% CPU time recently (threshold: 10%)
# dy_yield for //depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018//dy_M-100To200: 3469.7648647866
# dy_nevents for //depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018//dy_M-100To200: 92788
# 3469.7648647866

# %%
# do same for ewk sampel

filelist = glob.glob(f"{load_path}/ewk_lljj_mll105_160_ptj0")
# print(filelist)

total_integral = 0
for region in ["h-peak","h-sidebands"]:
    for file in filelist:
        events = dak.from_parquet(f"{file}/*.parquet")
        # events = dak.from_parquet(f"{file}/*/*.parquet")
        events = ak.zip({field: events[field] for field in V1_fields_2compute}).compute()
        events = applyVBF_cutV1(events)
        events = filterRegion(events, region=region)
        dy_yield = ak.sum(events.wgt_nominal)
        dy_nevents = ak.num(events.wgt_nominal, axis=0)
        # dy_yield = ak.sum(events.wgt_nominal).compute()
        # dy_nevents = ak.num(events.wgt_nominal, axis=0).compute()
    
        print(f"yield for {file} {region}: {dy_yield}")
# Out:
# 2025-01-09 19:30:16,214 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-09 19:30:16,341 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# yield for //depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018//ewk_lljj_mll105_160_ptj0 h-peak: 125.8663830517629
# 2025-01-09 19:30:17,269 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-09 19:30:17,299 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-09 19:30:17,371 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# yield for //depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018//ewk_lljj_mll105_160_ptj0 h-sidebands: 107.88340534697751

# %%
# do same for ewk sampel

filelist = glob.glob(f"{load_path}/vbf_powheg_dipole")
# print(filelist)

total_integral = 0
for region in ["h-peak","h-sidebands"]:
    for file in filelist:
        events = dak.from_parquet(f"{file}/*.parquet")
        # events = dak.from_parquet(f"{file}/*/*.parquet")
        events = ak.zip({field: events[field] for field in V1_fields_2compute}).compute()
        events = applyVBF_cutV1(events)
        events = filterRegion(events, region=region)
        dy_yield = ak.sum(events.wgt_nominal)
        dy_nevents = ak.num(events.wgt_nominal, axis=0)
        # dy_yield = ak.sum(events.wgt_nominal).compute()
        # dy_nevents = ak.num(events.wgt_nominal, axis=0).compute()
    
        print(f"yield for {file} {region}: {dy_yield}")
# Out:
# 2025-01-09 19:30:43,992 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-09 19:30:44,016 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# yield for //depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018//vbf_powheg_dipole h-peak: 11.85564329646733
# 2025-01-09 19:30:45,088 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-09 19:30:45,197 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2025-01-09 19:30:45,273 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# yield for //depot/cms/users/yun79/hmm/copperheadV1clean/ul_yun_Dec12_JecOff_JesJerUncOn/stage1_output/2018//vbf_powheg_dipole h-sidebands: 0.18357360850705176

# %%
! ls /depot/cms/users/yun79/hmm/copperheadV1clean/DmitryMaster_JECoff_GeofitFixed_Oct29/stage1_output/2018/dy_m105_160_amc
# Out:
# 001a0b68977f160cbdea9addb8b8d62c.parquet
# 001b9f33d62357037a3b1baff5135f49.parquet
# 0042b5b6cc2e80ae841fffe018f06781.parquet
# 00ea897bc8928d1f7a7df42f4207e033.parquet
# 0183f6d1f5c941bdbec2ce2c13dfd6a9.parquet
# 022d078f8178e1a7215d298862ec6d8f.parquet
# 02470fdac661d52b8116cb3c7db13138.parquet
# 0309bb4e56abdbad340083a422d50148.parquet
# 030c225fef8b7cfdb6d433fe691c44c6.parquet
# 03be8bed7e70bc7b0dd6c557f51d0341.parquet
# 05bccdd6c9004b818081f8e86cda7086.parquet
# 067e58cea84904cb8db4236bf83c4ee8.parquet
# 0724ba603a7271dbab354db8f4e40460.parquet
# 07d822d987b1bfaa0dee360e2c139da9.parquet
# 07ecd20fac9c9d74efa02a2ced6e6a3c.parquet
# 08a263b5aa7afd8168dabe5146ca8ca6.parquet
# 08a9b357ce6248b4f75edbb8fc42ea62.parquet
# 08b5544ac4ba4c6fcb061071b147dd91.parquet
# 0998d9bb3dfc14d21f6fbb52ff0733ee.parquet
# 09d34b596de17c7d60ca394cf304dd6a.parquet
# 09e0d7990f9e962e14df1a13c35a95cb.parquet
# 0a92a353e22de4f7aeb8fb16db1e6c60.parquet
# 0be379f3570fe35ed5cec324c3c3a71c.parquet
# 0c53f1f8ffcdf75e7a066dc1003659f2.parquet
# 0c8cdf233b391d5b8e11a7ebe04b66da.parquet
# 0d4e1587957ce8b27bea13d6293e59dd.parquet
# 64745c324b566eb2b6f53d1d05e3ea33.parquet
# 649f0bc5c81c8887c648f4297e740ca1.parquet
# 64c313f3497c51d5abc01a267dbb8e44.parquet
# 65569e89ffc25c138baa9481d4b319b0.parquet
# 6587190bf2a5faf162247702e39f7e1d.parquet
# 65938335e2c35183d57b894283c766d0.parquet
# 66213fc4965a04414f6875da752b3b02.parquet
# 6643b25c6e4ca723287c9961574cc956.parquet
# 665f73c7133371c0b55224cf821747db.parquet
# 67047e9bd449f14d9df518889f6c490d.parquet
# 678da8bd68c5d933deabff7f24f12f64.parquet
# 68f4964eb3827d906c2de677fba9eafc.parquet
# 6938a9bf72ffc600c7c00c29f2b5b0ce.parquet
# 6959d55d3577ea25cfed544efad969bb.parquet
# 69d177ceba318380a931d92476d09d37.parquet
# 6a96a9da48767a7fec959713ccc0e536.parquet
# 6aa4121c4ddbf0d4f0ffd0208ad4c778.parquet
# 6aa95e13942b6d022808f2eb617dece8.parquet
# 6abf236bd65eb8936428661ac5f05dac.parquet
# 6b3b1225acefd535444ca69bd059a00e.parquet
# 6b860e8bdf681e56ed75508b2a5d3a18.parquet
# 6ca1478b9aeb58da9c7f5aea6b416798.parquet
# 6caed84105fc2f84d0233038275e17c8.parquet
# 6cc7b9c04962e2237652e1cf8b9af4ba.parquet
# 6cf84d1d0fa59d5f88b4e46f3b43f7bf.parquet
# 6da280d85fafe1a12ac8559d36d51cad.parquet
# 6e9efd8696e289177b4d305c2877ac27.parquet
# 6f7af6c19256301a8ce0abffaafb7c60.parquet
# 703cba16036099f8df4a283443a602b6.parquet
# 70b27a24016bbd6374717a5cd6de4625.parquet
# 71c327fd9cec2ffc5497f48aaa47b955.parquet
# 72ae3a81f2c818d0009a68e26e25ca9c.parquet
# 73dff019014d93784effd1ac687c9c02.parquet
# 750a51150cf36b66246a35ae42eaae1c.parquet
# 75558f4fd4c3da33b9416c787598adde.parquet
# 75c0be709291fc6a0882e526a6afd821.parquet
# 76aa0067091df4d0635fde88b6393ef9.parquet
# 777538429ec20f02bf2e01913fc1025f.parquet
# 784f9e17d017d58e8d66f99582ff2fb1.parquet
# 78561c0f78a7e2fce6bd516112d6392d.parquet
# 78754bdd896d8c95bbf1cb597b719123.parquet
# 7985729958807dfd840710b19fd4ed8b.parquet
# 7a03d9ba8a67b02a2f17a73636168b74.parquet
# 7a4129afad9427911a0e2728baf291c7.parquet
# 7a9cca52d12a539067660f519a14ca80.parquet
# 7bd8bf06526b0e8edec0dce31e308ba2.parquet
# 7be2e9041e200410da74b61746f022c0.parquet
# 7c1f1b2939998e99908548f834162839.parquet
# 7c7d10e21b03b06014b112cc78589a58.parquet
# 7c82a505b5b5f1771184b029877cff87.parquet
# 7c91eaa59e2b3fbeda5f66e9e1f8fa90.parquet
# 7cf40f7384d639a1bcf74f049e6a1cac.parquet
# 7e54f671d656e96f0615fba3299e25f6.parquet
# 7e7a9fd1c7bad514e912861a22d2e62a.parquet
# 80253bc3c8ffb8fb49aa2f72f9bb166c.parquet
# 80a1dc426c9f89b178a61f0056c1356f.parquet
# 816f5b43f9e07d6ed00039799f82524e.parquet
# ecaad69be41f4505dee0ffbda44ff725.parquet
# ecc3b4eecc1b0e2e19bffea38f174fec.parquet
# ecfa7a09d8eede262e07be711c43e37e.parquet
# ee4063822da8bf632ea22ebebbf4f5ac.parquet
# ee6363af358fa98ab8a3d8ab70bd3504.parquet
# ee789f194d5256e3e91b3b53291d936e.parquet
# eea823d50795918360383575f37d122d.parquet
# ef0225dd568849e61e65b893848e0c7e.parquet
# ef25f2cdde6ad6a1e144d6b8d8ea0231.parquet
# ef2d36ff2ba19f6e9840cf057e0979fe.parquet
# ef8b2e6b6eb989b9105704366d49fb39.parquet
# efabbf067ad655b2b9355dbe7f651d40.parquet
# f0179d7763588de56971ece32add898a.parquet
# f0a86e84a132c3b2d15ae5351ed209a0.parquet
# f1bb43b49b55690ba3f9ed118fc8641c.parquet
# f1de1e906c3dbb4f4937cd0903b16031.parquet
# f229b8a2772699bc589439214e7361ea.parquet
# f2367f2fdb287d0c399480e74638d699.parquet
# f2436f65b56a6fea33efe0bb96509830.parquet
# f27899854972acda1387693861b52cc5.parquet
# f2c270792dc3f96dac4d99ebe4806d4e.parquet
# f4b148ecbed0c3321eac2adcb0059c96.parquet
# f5580d6ccdef152c8be8ad7ae089c653.parquet
# f64c9f232daf9c2c8e8ae7437c7aeeb9.parquet
# f6e7052c989cfc232b617add6b5f150f.parquet
# f721821eea2519826c8dda88085bd89f.parquet
# f7f98bf15a51d406f5354e98a97004e2.parquet
# f9ccb922bbd5c7271908710c9df3684e.parquet
# fa34d6a2db670ef1c827f2cee6b82564.parquet
# fbb36d7602c17db9773b003644a60855.parquet
# fc1ccc15a108e49b26494a167276327b.parquet
# fc6e5b7091c4f1580bf8206f70bbe95f.parquet
# fc82b1f26f78d312d29f9bba6ffdbcf5.parquet
# fcbc2d6369a2c2ea6a27599710f5f4f3.parquet
# fd0608fe45c6ed7169f7e4fcda8e8dc4.parquet
# fd935942a89d514a79fb63560eb64cd0.parquet
# fdc4df3ad2dd59bb752dfcc2c0164343.parquet
# fe3a2dfa3cb799d9442048ea502e67df.parquet
# fe47c41928a7f419822be44446b0162b.parquet
# fe533cc92b41e822df09903c285f8537.parquet
# fe6446e9a86d5306b1b1ea9e04590dc5.parquet

# %%
# import uproot
# import glob
# import numba
# import numpy as np
# import concurrent.futures

# @numba.jit(parallel=True, nopython=False)
# def getBadFileIdx(fnames):
#     bad_files = np.zeros(len(fnames))
#     for file_idx in numba.prange(len(fnames)):
#         up_file = uproot.open(fnames[file_idx]) 
#         if not ("HLT_IsoMu27" in up_file['Events'].keys()):
#             # print(fnames[file_idx])
#             bad_files[file_idx] = 1
#             # bad_files.append(file)
#     return bad_files

# %%
len(results)
# Out:
# 2500

# %%
import ROOT as rt

file = rt.TFile(filelist[0])
file.ls()
# Out:
# TFile**		/eos/purdue/store/group/local/hmm/FSRnano18D_NANOV10b/SingleMuon/RunIISummer16MiniAODv3_FSRnano18D_NANOV10b_un2018D-22Jan2019-v2/200408_223523/0000/nano18D_NANO_1.root
#  TFile*		/eos/purdue/store/group/local/hmm/FSRnano18D_NANOV10b/SingleMuon/RunIISummer16MiniAODv3_FSRnano18D_NANOV10b_un2018D-22Jan2019-v2/200408_223523/0000/nano18D_NANO_1.root
#   KEY: TObjString	tag;1	Collectable string class
#   KEY: TTree	Events;1	Events
#   KEY: TTree	LuminosityBlocks;1	LuminosityBlocks
#   KEY: TTree	Runs;1	Runs
#   KEY: TTree	MetaData;1	Job metadata
#   KEY: TTree	ParameterSets;1	Parameter sets

# %%
! ls /depot/cms/users/yun79/hmm/copperheadV1clean/DmitryMaster_w_centralRERECO_Oct25/stage1_output/2017
# Out:
# data_B

# %%
! ls /depot/cms/users/yun79/hmm/copperheadV1clean/RERECO_Oct24/stage1_output/2018/
# Out:
# data_A	data_B	data_C	data_D

# %%
# events_bkg = dak.from_parquet(bkg_l) 
# events_bkg = ak.zip({field : events_bkg[field] for field in fields2compute}).compute()

# normal from_parquet doesn't work, so using convoluted concatenating method
# year = 2018
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}*/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}/f1_0"
load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/*/f1_0"
events_data = dak.from_parquet(f"{load_path}/data_*/*/*.parquet")
events_data = ak.zip({field: events_data[field] for field in fields2compute}).compute()
events_data = applyGGH_cut(events_data)
data_yield = ak.num(events_data.dimuon_mass, axis=0)

# %%
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2RERECO_data_OCt14_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2RERECO_data_w_LumiMask_JETID_JETPUID_BTag_DefaultJEC_Oct15_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2RERECO_data_w_LumiMask_JETID_JETPUID_BTag_Oct16_2014/{year}_RERECO/f1_0"
load_path = f"/depot/cms/users/yun79/results/stage1/Run2RERECO_data_w_LumiMask_JETID_JETPUID_BTag_DefaultJEC_Oct15_2014/*_RERECO/f1_0"


events_data_rereco = dak.from_parquet(f"{load_path}/data_*/*/*.parquet")
events_data_rereco = ak.zip({field: events_data_rereco[field] for field in fields2compute}).compute()
events_data_rereco = applyGGH_cut(events_data_rereco)
data_yield_rereco = ak.num(events_data_rereco.dimuon_mass, axis=0)

# %%
print(data_yield)
print(data_yield_rereco)
# Out:
# 1609961
# 1610974

# %%
"""
similar test, but with data_C 2018 UL only
"""
# normal from_parquet doesn't work, so using convoluted concatenating method
year = 2018
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}*/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}preVFP/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/{year}/f1_0"
load_path = f"/depot/cms/users/yun79/results/stage1/BDT_inputValidation_JetIdUpdate/20*/f1_0"

# events_data = dak.from_parquet(f"{load_path}/data_C/*/*.parquet")
events_data = dak.from_parquet(f"{load_path}/data_*/*/*.parquet")
events_data = ak.zip({field: events_data[field] for field in fields2compute}).compute()
events_data = applyGGH_cut(events_data)
data_yield = ak.num(events_data.dimuon_mass, axis=0)

# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_DefaultJEC_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_DefaultJEC_RochOff_GeofitOff_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_DefaultJEC_RochOff_GeofitOff_FsrOff_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_DefaultJEC_RochOff_GeofitOff_ElectronEcalGapOn_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_DefaultJEC_ElectronEcalGapOn_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_ElectronEcalGapOn_TriggerMatchOff_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_LumiMask_ElectronEcalGapOn_TriggerMatchOff_MuLeadingPtCutOff_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_ElectronEcalGapOn_TriggerMatchOff_MuLeadingPtCutOff_DefaultJEC_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_ElectronEcalGapOnNCorrected_TriggerMatchOff_MuLeadingPtCutOff_DefaultJEC_Oct16_2014/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2UL_data_w_ElectronEcalGapOnNCorrected_MuLeadingPtCutOff_defaultJEC_BtagCorrected_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_newEventFilter_Oct16_2014/{year}_RERECO/f1_0"


# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_newEventFilter_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_TriggerMatchOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_Oct16_2014/*_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_TriggerMatchOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_Oct16_2014/*_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_TriggerMatchOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/Run2_data_w_MuLeadingPtCutOff_TriggerMatchOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_HltFillNoneTest_Oct16_2014/{year}_RERECO/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_WgtON_original_AN_BDTV2_Oct18/{year}/f1_0"
# load_path = f"/depot/cms/users/yun79/results/stage1/BDT_WgtON_original_AN_BDTV2_Oct18/*/f1_0"
load_path = f"/depot/cms/users/yun79/results/stage1/RERECO_Run2_data_w_MuLeadingPtCutOff_defaultJEC_BtagCorrected_newEventFilter_HLTFixed_HltFillNoneTest_Oct18/*_RERECO/f1_0"



# events_data_rereco = dak.from_parquet(f"{load_path}/data_C/*/*.parquet")
events_data_rereco = dak.from_parquet(f"{load_path}/data_*/*/*.parquet")
events_data_rereco = ak.zip({field: events_data_rereco[field] for field in fields2compute}).compute()
events_data_rereco = applyGGH_cut(events_data_rereco)
data_yield_rereco = ak.num(events_data_rereco.dimuon_mass, axis=0)
print(data_yield)
print(data_yield_rereco)
# Out:
# 1606887
# 1620838

# %%
# isnan = np.isnan(ak.to_numpy(events_bkg.wgt_nominal_total))
# np.sum(isnan)
# # hist_bkg

# %%
# nbins = 60
# bin_map = {
#      "dimuon_pt": [0,200, nbins], 
#     "dimuon_rapidity" : [-2.5,2.5, nbins], 
#     "dimuon_eta" : [-8,8, nbins],
# }
with open("./plot_settings_gghCat_BDT_input.json", "r") as file:
    bin_map = json.load(file)
# bin_map

# %%
year = "Run2"
# for field in cols_of_interest:
for field in (["jj_dPhiV2"]):
    binning = np.linspace(*bin_map[field]["binning_linspace"])
    xmin = bin_map[field]["binning_linspace"][0]
    xmax = bin_map[field]["binning_linspace"][1]
    hist_sig, edges = getHist(events_sig, field, binning)
    # raise ValueError
    hist_bkg, edges = getHist(events_bkg, field, binning)
    fig, ax_main = plt.subplots()
    # plt.stairs(hist_sig,edges=edges,label="signal", color="blue")
    # plt.stairs(hist_bkg,edges=edges,label="background", color="red")
    hep.histplot(
        hist_sig, 
        bins=binning, 
        stack=False, 
        histtype='step', 
        color='blue', 
        label='signal', 
        ax=ax_main,
    )
    # print(f"hist_bkg: {hist_bkg}")
    hep.histplot(
        hist_bkg, 
        bins=binning, 
        stack=False, 
        histtype='step', 
        color='red', 
        label='background', 
        ax=ax_main,
    )
    ax_main.set_xlabel(bin_map[field]["xlabel"])
    ax_main.set_ylabel("A.U.")
    if bin_map[field]["logscale"]:
        plt.yscale('log')  # Set y-axis to log scale
        plt.ylim(1e-3, 1)
    plt.xlim(xmin, xmax)
    plt.legend()
    # plt.show()
    CenterOfMass = 13
    # lumi = 59.97 # 2018 lumi value
    lumi = 137.9 # Run2 value
    hep.cms.label(data=True, loc=0, label="Private Work", com=CenterOfMass, ax=ax_main, lumi=lumi)
    plt.savefig(f"plots/BDT_input{year}_{field}")
    plt.clf()
# Out:
# getHist weight sum: 13.84659559419017
# getHist value sum: -13723.506476295119
# getHist weight: [0.000352, 0.000295, 0.000369, 0.000393, ..., 2.4e-05, 2.13e-05, 2.67e-05]
# getHist value: [-1, -1, -1, -1, 2.36, -1, -1, 1.37, ..., -1, -1, -1, -1, -1, 2.56, 1.86, -1]
# getHist hist b4 normalization: [0.0459, 0.0445, 0.0458, 0.0512, 0.0449, ..., 0.0584, 0.069, 0.065, 0.0677]
# np.sum(hist): 0.9999999999999999
# getHist weight sum: 809642.0579307787
# getHist value sum: -9613472.744227482
# getHist weight: [0.0325, 0.0273, 0.0258, 0.0332, 0.0251, ..., 0.0132, 0.0178, 0.0119, 0.0143]
# getHist value: [-1, -1, -1, -1, -1, -1, -1, 1.44, ..., -1, 2.78, 2.18, -1, 2.33, -1, 1.8, 2.28]
# getHist hist b4 normalization: [1.18e+03, 1.2e+03, 1.2e+03, 1.24e+03, ..., 3.39e+03, 3.58e+03, 3.7e+03]
# np.sum(hist): 0.9999999999999998

# %%
ak.sum(ak.is_none(events_bkg.jj_dPhiV2))
# Out:
# 0

# %%
import awkward as ak
import numpy as np

A = ak.Array([None,1])
# np.isnan(ak.to_numpy(A))
np.isnan( ak.Array([None,1]))
np.any(ak.is_none(ak.Array([None,1])))
# Out:
# True

# %%
np.logspace(2, 3, num=9+1)
# Out:
# array([ 100.        ,  129.1549665 ,  166.81005372,  215.443469  ,
#         278.25594022,  359.38136638,  464.15888336,  599.48425032,
#         774.26368268, 1000.        ])

# %%
np.logspace(-1, 0, num=9+1)
# Out:
# array([0.1       , 0.12915497, 0.16681005, 0.21544347, 0.27825594,
#        0.35938137, 0.46415888, 0.59948425, 0.77426368, 1.        ])

# %%
sorted([0.5, 0.15, 0.83, 0.02, 0.28, 0.67])
# Out:
# [0.02, 0.15, 0.28, 0.5, 0.67, 0.83]

# %%
# import dask_awkward as dak
# import awkward as ak
# from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
# from dask_awkward.lib.core import map_partitions
# import numpy as np

# input_dict = {"test": {
#     "files": {
#         # "root://eos.cms.rcac.purdue.edu:1094//store/mc/RunIISummer20UL18NanoAODv9/DYJetsToLL_M-100to200_TuneCP5_13TeV-amcatnloFXFX-pythia8/NANOAODSIM/106X_upgrade2018_realistic_v16_L1v1-v1/40000/AA6F89B0-EDAA-3942-A3BB-BC3709722EB4.root": {
#         "root://eos.cms.rcac.purdue.edu//store/group/local/hmm/FSRnano18D_NANOV10b/SingleMuon/RunIISummer16MiniAODv3_FSRnano18D_NANOV10b_un2018D-22Jan2019-v2/200408_223523/0004/nano18D_NANO_4814.root" : {
#             "object_path": "Events", "steps": [[0, 10000],[10000, 20000]], "num_entries": 19, "uuid": "77528b92-6481-11ef-aeb3-83890d0abeef"}
#     }, 
#     "form": None, "metadata": {"sumGenWgts": 217532.83170000004, "nGenEvts": 1959, "data_entries": None, "fraction": 1.0, "original_fraction": 1.0, "is_mc": True, "dataset": "test"}}}

# events = NanoEventsFactory.from_root(
#     input_dict['test']['files'],
#     schemaclass=NanoAODSchema,
# ).events()

# %%
ak.sum(events.GenJet.pt < 10).compute()
# Out:
# /depot/cms/kernels/root632/lib/python3.12/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/root632/lib/python3.12/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 0

# %%
# import ROOT as rt

# # file = rt.TFile("/eos/purdue/store/group/local/hmm/FSRnano18D_NANOV10b/SingleMuon/RunIISummer16MiniAODv3_FSRnano18D_NANOV10b_un2018D-22Jan2019-v2/200408_223523/0004/nano18D_NANO_4814.root")
# file = rt.TFile("/eos/purdue/store/group/local/hmm/FSRnano18D_NANOV10b/SingleMuon/RunIISummer16MiniAODv3_FSRnano18D_NANOV10b_un2018D-22Jan2019-v2/200408_223523/0004/nano18D_NANO_4813.root")
# Out:
# Warning in <TClass::Init>: no dictionary for class edm::Hash<1> is available
# Warning in <TClass::Init>: no dictionary for class edm::ParameterSetBlob is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessHistory is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessConfiguration is available
# Warning in <TClass::Init>: no dictionary for class pair<edm::Hash<1>,edm::ParameterSetBlob> is available
