# %%
! ls /work/users/yun79/vbf_Run2dataCard/datacards/2018_jul7_score_dnn_allyears_128_64_32/
# Out:
# combined-Copy1.txt     datacard_vbf_SB.txt	    shapes_vbf_SB.root
# combined_original.txt  datacard_vbf_SR.txt	    shapes_vbf_SR_original.root
# combined.root	       diff.log			    shapes_vbf_SR.root
# combined.txt	       old			    Untitled.ipynb
# combined.txt~	       shapes_vbf_SB_original.root  yun_workspace

# %%
# official_path = " /work/users/yun79/vbf_Run2dataCard/datacards/2018_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# file_dmitry = rt.TFile(official_path)

# %%
# file_dmitry.ls()
up = file_dmitry["qqH_hmm_jesAbsoluteUp"]
down = file_dmitry["qqH_hmm_jesAbsoluteDown"]
base = file_dmitry["qqH_hmm"]

# %%
# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas for 3 Histograms", 800, 600)

# Create three TH1D histograms
hist1 = base
hist2 = up
hist3 = down


# Set histogram styles
hist1.SetLineColor(rt.kGreen)
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist1.SetLineWidth(2)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist1.Draw("HIST")  # Draw the first histogram
hist2.Draw("HIST SAME")  # Overlay the second histogram
hist3.Draw("HIST SAME")  # Overlay the third histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist1, "base", "l")
legend.AddEntry(hist2, "Absolute Up", "l")
legend.AddEntry(hist3, "Absolute Down", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("Absolute Variation.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file Absolute Variation.png has been created

# %%
# my_path = "/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Nov26_puidWgtOnJerUncOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# file_mine = rt.TFile(my_path)

# %%
up = file_mine["VBF_AbsoluteUp"]
down = file_mine["VBF_AbsoluteDown"]
base = file_mine["VBF"]
# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas for 3 Histograms", 800, 600)

# Create three TH1D histograms
hist1 = base
hist2 = up
hist3 = down


# Set histogram styles
hist1.SetLineColor(rt.kGreen)
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist1.SetLineWidth(2)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist2.Draw("HIST ")  # Overlay the third histogram
hist1.Draw("HIST SAME")  # Draw the first histogram
hist3.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist1, "base", "l")
legend.AddEntry(hist2, "Absolute Up", "l")
legend.AddEntry(hist3, "Absolute Down", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("Absolute Variation My.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file Absolute Variation My.png has been created

# %%
import numpy as np
old_hist = file_dmitry["qqH_hmm"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: newHist (Potential memory leak).

# %%
up = file_mine["VBF"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist2.Draw("HIST ")  # Overlay the third histogram
hist3.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, "Hyeon-Seo VBF", "l")
legend.AddEntry(hist3, "Dmitry VBF", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("VBF Dmitry vs HyeonSeo.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF Dmitry vs HyeonSeo.png has been created

# %%
import numpy as np
old_hist = file_dmitry["EWK"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: newHist (Potential memory leak).

# %%
up = file_mine["EWK"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist2.Draw("HIST ")  # Overlay the third histogram
hist3.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, "Hyeon-Seo VBF", "l")
legend.AddEntry(hist3, "Dmitry VBF", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("VBF Dmitry vs HyeonSeo.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF Dmitry vs HyeonSeo.png has been created

# %%
import numpy as np
old_hist = file_dmitry["ggH_hmm"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: newHist (Potential memory leak).

# %%
up = file_mine["ggH"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist2.Draw("HIST ")  # Overlay the third histogram
hist3.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, "Hyeon-Seo VBF", "l")
legend.AddEntry(hist3, "Dmitry VBF", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("VBF Dmitry vs HyeonSeo.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF Dmitry vs HyeonSeo.png has been created

# %%
import numpy as np
old_hist = file_dmitry["data_obs"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: newHist (Potential memory leak).

# %%
up = file_mine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist2.Draw("HIST ")  # Overlay the third histogram
hist3.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, "Hyeon-Seo VBF", "l")
legend.AddEntry(hist3, "Dmitry VBF", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("VBF Dmitry vs HyeonSeo.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF Dmitry vs HyeonSeo.png has been created

# %%
import numpy as np
old_hist = file_dmitry["DYJ01"]
old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist

up = file_mine["DYJ01"]
up.Add(file_mine["DYJ2"])


# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist2.Draw("HIST ")  # Overlay the third histogram
hist3.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, "Hyeon-Seo VBF", "l")
legend.AddEntry(hist3, "Dmitry VBF", "l")
legend.Draw()

# Display the canvas
canvas.Draw()
canvas.SaveAs("VBF Dmitry vs HyeonSeo.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: newHist (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF Dmitry vs HyeonSeo.png has been created

# %%
! ls /depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec04NewBtag/
# Out:
# stage1_output  stage2_histograms  stage2_unbinned  stage3_datacards

# %%
# file_mine.ls()
file_mine["qqH_hmm"].Integral()
# Out:
# 11.736332731652153

# %%
import uproot
import ROOT as rt
import os

year = "2018"
# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Nov26_puidWgtOnJerUncOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec04NewBtag/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec05_btagSystFixed_JesJerUncOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec05_btagSystFixed_JesJerUncOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"



file_mine = rt.TFile(my_path)

# processes = ["qqH_hmm", "ggH_hmm", "EWK", "DYJ01", "DYJ2", "TT+ST", "VV"]
processes = ["qqH_hmm", ]

# process_map = {
#     "VBF": "qqH_hmm",
#     "ggH": "ggH_hmm",
# }
jes_variations = ['Absolute', 'Absolute2018', 'BBEC1', 'BBEC12018', 'EC2', 'EC22018', 'HF', 'HF2018', 'RelativeBal', 'RelativeSample2018', 'FlavorQCD', ]
# jes_variations = []
other_shape_variations = ["LHEFacDY", "EWKPartonShower", "SignalPartonShower", "LHEFacEWK",
# "LHEFacTT+ST",
# "LHEFacggH",
# "LHERenDY",
# "LHERenEWK",
# "LHERenTT+ST",
# "LHERenggH",
# f"muID{year}",
# f"muIso{year}",
# f"muTrig{year}",
# f"pdf_2rmsDY{year}",
# f"pdf_2rmsVBF{year}",
# f"pdf_2rmsggH{year}",
# "btag_cferr1",
# "btag_cferr2",
# "btag_hf",
# "btag_hfstats1",
# "btag_hfstats2",
# "btag_jes",
# "btag_lf",
# "btag_lfstats1",
# "btag_lfstats2",
# "THU_VBF_JET01",
# "THU_VBF_Mjj1000",
# "THU_VBF_Mjj120",
# "THU_VBF_Mjj1500",
# "THU_VBF_Mjj350",
# "THU_VBF_Mjj60",
# "THU_VBF_Mjj700",
# "THU_VBF_PTH200",
# "THU_VBF_PTH25",
# "THU_VBF_Yield",
# f"pu_wgt{year}",
# "qgl_wgt",
# f"l1prefiring_wgt{year}",
"jer1",
"jer2",
"jer3",
"jer4",
"jer5",
"jer6",
                          
]

all_variations = jes_variations + other_shape_variations

for process in processes:
    for variation in all_variations:
        up_name = f"{process}_{variation}Up;1"
        uproot_file = uproot.open(my_path)
        if up_name not in uproot_file.keys():
            print(f"var name {up_name} not in file!")
            continue
        
        
        up = file_mine[f"{process}_{variation}Up"]
        down = file_mine[f"{process}_{variation}Down"]
        base = file_mine[f"{process}"]
        print(f"{variation} {process} base integral: {base.Integral()}")
        print(f"{variation} {process} up integral: {up.Integral()}")
        print(f"{variation} {process} down integral: {down.Integral()}")
        # Create a canvas
        canvas = rt.TCanvas("canvas", "Canvas for 3 Histograms", 800, 600)
        
        # Create three TH1D histograms
        hist1 = base
        hist2 = up
        hist3 = down
        
        
        # Set histogram styles
        hist1.SetLineColor(rt.kGreen)
        hist2.SetLineColor(rt.kBlue)
        hist3.SetLineColor(rt.kRed)
        hist1.SetLineWidth(2)
        hist2.SetLineWidth(2)
        hist3.SetLineWidth(2)
        
        # Draw the histograms on the canvas
        hist2.Draw("HIST ")  # Overlay the third histogram
        hist1.Draw("HIST SAME")  # Draw the first histogram
        hist3.Draw("HIST SAME")  # Overlay the second histogram
        
        # Add a legend
        legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
        legend.AddEntry(hist1, "base", "l")
        legend.AddEntry(hist2, f"{variation} Up", "l")
        legend.AddEntry(hist3, f"{variation} Down", "l")
        legend.Draw()
        
        # Display the canvas
        canvas.SetLogy()
        canvas.Draw()
        directory_path = "plots/my_workspace"
        if not os.path.exists(directory_path):
            os.makedirs(directory_path)
        canvas.SaveAs(f"plots/my_workspace/yun_var_{process}_{variation}.png")  # Save the canvas as an image if needed
# Out:
# Absolute qqH_hmm base integral: 11.759849228789854
# Absolute qqH_hmm up integral: 12.11848113723042
# Absolute qqH_hmm down integral: 11.524034774805553
# Absolute2018 qqH_hmm base integral: 11.759849228789854
# Absolute2018 qqH_hmm up integral: 11.907475351571286
# Absolute2018 qqH_hmm down integral: 11.731467582512987
# BBEC1 qqH_hmm base integral: 11.759849228789854
# BBEC1 qqH_hmm up integral: 11.836193673105866
# BBEC1 qqH_hmm down integral: 11.802470252550078
# BBEC12018 qqH_hmm base integral: 11.759849228789854
# BBEC12018 qqH_hmm up integral: 11.845521857242687
# BBEC12018 qqH_hmm down integral: 11.790652882180009
# EC2 qqH_hmm base integral: 11.759849228789854
# EC2 qqH_hmm up integral: 11.826790291924887
# EC2 qqH_hmm down integral: 11.810075109393766
# EC22018 qqH_hmm base integral: 11.759849228789854
# EC22018 qqH_hmm up integral: 11.86882140108791
# EC22018 qqH_hmm down integral: 11.7664355985772
# HF qqH_hmm base integral: 11.759849228789854
# ...

# %%
import numpy as np
year = "2018"
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
file_dmitry = rt.TFile(official_path)

def changeEdges(hist_dmitry):
    new_edges = np.arange(14, dtype=np.double)
    n_bins = len(new_edges) - 1
    title = hist_dmitry.GetName()
    new_hist = rt.TH1D(title, "", n_bins, new_edges)
    for i in range(1, hist_dmitry.GetNbinsX() + 1):
            bin_center = hist_dmitry.GetBinCenter(i)
            bin_content = hist_dmitry.GetBinContent(i)
            new_hist.SetBinContent(i, bin_content)
            # new_hist.Fill(bin_center, bin_content)
                
    return new_hist
    
processes = ["qqH_hmm", "ggH_hmm", "EWK", "DYJ01", "DYJ2", "TT+ST", "VV"]
# process_map = {
#     "VBF": "qqH_hmm",
#     "ggH": "ggH_hmm",
# }
jes_variations = ['jesAbsolute', 'jesAbsolute2018', 'jesBBEC1', 'jesBBEC12018', 'jesEC2', 'jesEC22018', 'jesHF', 'jesHF2018', 'jesRelativeBal', 'jesRelativeSample2018', 'jesFlavorQCD', ]
# jes_variations = []
other_shape_variations = ["LHEFac_DY", "EWKPartonShower", "SignalPartonShower", "LHEFac_EWK",
# "LHEFac_TT+ST",
# "LHEFac_ggH",
# "LHERen_DY",
# "LHERen_EWK",
# "LHERen_TT+ST",
# "LHERen_ggH",
# "muID2018",
# "muIso2018",
# "muTrig2018",
# "pdf_2rms_DY2018",
# "pdf_2rms_VBF2018",
# "pdf_2rms_ggH2018",
# "btag_wgt_cferr1",
# "btag_wgt_cferr2",
# "btag_wgt_hf",
# "btag_wgt_hfstats1",
# "btag_wgt_hfstats2",
# "btag_wgt_jes",
# "btag_wgt_lf",
# "btag_wgt_lfstats1",
# "btag_wgt_lfstats2",
# "THU_VBF_JET01",
# "THU_VBF_Mjj1000",
# "THU_VBF_Mjj120",
# "THU_VBF_Mjj1500",
# "THU_VBF_Mjj350",
# "THU_VBF_Mjj60",
# "THU_VBF_Mjj700",
# "THU_VBF_PTH200",
# "THU_VBF_PTH25",
# "THU_VBF_Yield",
# "pu_wgt2018",
"pu_wgt2017",
f"l1prefiring_wgt{year}",
"qgl_wgt",
"jer12018",
"jer22018",
"jer32018",
"jer42018",
"jer52018",
"jer62018",
                          
]

all_variations = jes_variations + other_shape_variations

for process in processes:
    for variation in all_variations:
        up_name = f"{process}_{variation}Up;1"
        uproot_file = uproot.open(official_path)
        if up_name not in uproot_file.keys():
            print(f"var name {up_name} not in file!")
            continue
        
        
        up = changeEdges(file_dmitry[f"{process}_{variation}Up"])
        down = changeEdges(file_dmitry[f"{process}_{variation}Down"])
        base = changeEdges(file_dmitry[f"{process}"])
        # Create a canvas
        canvas = rt.TCanvas("canvas", "Canvas for 3 Histograms", 800, 600)
        
        # Create three TH1D histograms
        hist1 = base
        hist2 = up
        hist3 = down
        
        
        # Set histogram styles
        hist1.SetLineColor(rt.kGreen)
        hist2.SetLineColor(rt.kBlue)
        hist3.SetLineColor(rt.kRed)
        hist1.SetLineWidth(2)
        hist2.SetLineWidth(2)
        hist3.SetLineWidth(2)
        
        # Draw the histograms on the canvas
        hist2.Draw("HIST ")  # Overlay the third histogram
        hist1.Draw("HIST SAME")  # Draw the first histogram
        hist3.Draw("HIST SAME")  # Overlay the second histogram
        
        # Add a legend
        legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
        legend.AddEntry(hist1, "base", "l")
        legend.AddEntry(hist2, f"{variation} Up", "l")
        legend.AddEntry(hist3, f"{variation} Down", "l")
        legend.Draw()
        
        # Display the canvas
        canvas.SetLogy()
        canvas.Draw()
        directory_path = "plots/dmitry_workspace"
        if not os.path.exists(directory_path):
            os.makedirs(directory_path)
        canvas.SaveAs(f"plots/dmitry_workspace/dmitry_var_{process}_{variation}.png")  # Save the canvas as an image if needed
# Out:
# var name qqH_hmm_LHEFac_DYUp;1 not in file!
# var name qqH_hmm_EWKPartonShowerUp;1 not in file!
# var name qqH_hmm_LHEFac_EWKUp;1 not in file!
# var name qqH_hmm_pu_wgt2017Up;1 not in file!
# var name ggH_hmm_LHEFac_DYUp;1 not in file!
# var name ggH_hmm_EWKPartonShowerUp;1 not in file!
# var name ggH_hmm_SignalPartonShowerUp;1 not in file!
# var name ggH_hmm_LHEFac_EWKUp;1 not in file!
# var name ggH_hmm_pu_wgt2017Up;1 not in file!
# var name EWK_LHEFac_DYUp;1 not in file!
# var name EWK_SignalPartonShowerUp;1 not in file!
# var name EWK_pu_wgt2017Up;1 not in file!
# var name DYJ01_EWKPartonShowerUp;1 not in file!
# var name DYJ01_SignalPartonShowerUp;1 not in file!
# var name DYJ01_LHEFac_EWKUp;1 not in file!
# var name DYJ01_pu_wgt2017Up;1 not in file!
# var name DYJ2_EWKPartonShowerUp;1 not in file!
# var name DYJ2_SignalPartonShowerUp;1 not in file!
# var name DYJ2_LHEFac_EWKUp;1 not in file!
# var name DYJ2_pu_wgt2017Up;1 not in file!
# ...

# %%
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
# official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)

# old_hist = file_dmitry["data_obs"]
old_hist = file_dmitry["data_obs"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist


up = file_mine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)

# Draw the histograms on the canvas
hist3.Draw("HIST ")  # Overlay the third histogram
hist2.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"Hyeon-Seo data {year}", "l")
legend.AddEntry(hist3, f"Dmitry data {year}", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
canvas.Draw()
canvas.SaveAs(f"data_obs comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file data_obs comparision 2018.png has been created

# %%
import ROOT as rt
import numpy as np

year = "2018"
# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"

file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_2018.root"
# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"

file_newmine = rt.TFile(my_newpath)
new = file_newmine["data_obs"]
# old_hist = file_newmine["data_obs"]
# new_edges = np.arange(14, dtype=np.double)
# n_bins = len(new_edges) - 1
# new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
# for i in range(1, old_hist.GetNbinsX() + 1):
#         bin_center = old_hist.GetBinCenter(i)
#         bin_content = old_hist.GetBinContent(i)
#         new_hist.SetBinContent(i, bin_content)
# new = new_hist


# down = file_dmitry["data_obs"]
old_hist = file_dmitry["data_obs"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"data {year}", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
hist2.Draw("HIST SAME")  # Overlay the second histogram
# hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 {year}", "l")
legend.AddEntry(hist3, f"Dmitry data {year}", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  {year}", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
canvas.Draw()
canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF comparision 2018.png has been created

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-sidebands_{year}.root"
# my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SB.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-sidebands_2018.root"
# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"

file_newmine = rt.TFile(my_newpath)
new = file_newmine["data_obs"]
# old_hist = file_newmine["data_obs"]
# new_edges = np.arange(14, dtype=np.double)
# n_bins = len(new_edges) - 1
# new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
# for i in range(1, old_hist.GetNbinsX() + 1):
#         bin_center = old_hist.GetBinCenter(i)
#         bin_content = old_hist.GetBinContent(i)
#         new_hist.SetBinContent(i, bin_content)
# new = new_hist


# down = file_dmitry["data_obs"]
old_hist = file_dmitry["data_obs"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"data {year}", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
hist2.Draw("HIST SAME")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 {year}", "l")
legend.AddEntry(hist3, f"Dmitry data {year}", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  {year}", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
canvas.Draw()
canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF comparision 2018.png has been created

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_2018.root"
my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"

file_newmine = rt.TFile(my_newpath)
new = file_newmine["EWK"]
# old_hist = file_newmine["data_obs"]
# new_edges = np.arange(14, dtype=np.double)
# n_bins = len(new_edges) - 1
# new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
# for i in range(1, old_hist.GetNbinsX() + 1):
#         bin_center = old_hist.GetBinCenter(i)
#         bin_content = old_hist.GetBinContent(i)
#         new_hist.SetBinContent(i, bin_content)
# new = new_hist


# down = file_dmitry["data_obs"]
old_hist = file_dmitry["EWK"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"EWK {year} sample comparison", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine["EWK"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
# hist2.Draw("HIST SAME")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 ", "l")
legend.AddEntry(hist3, f"Dmitry ", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  ", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
# canvas.SetTitle()
canvas.Draw()
# canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_2018.root"
my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"


file_newmine = rt.TFile(my_newpath)
new = file_newmine["DYJ01"]
# new.Add(file_newmine["DYJ2"])


# down = file_dmitry["data_obs"]
old_hist = file_dmitry["DYJ01"]
# old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"DYJ01 {year} sample comparison", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine["DYJ01"]
# up.Add(file_mine["DYJ2"])

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
hist2.Draw("HIST SAME")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 ", "l")
legend.AddEntry(hist3, f"Dmitry ", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  ", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
# canvas.SetTitle()
canvas.Draw()
# canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_2018.root"
my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"


file_newmine = rt.TFile(my_newpath)
new = file_newmine["DYJ2"]
# new.Add(file_newmine["DYJ2"])


# down = file_dmitry["data_obs"]
old_hist = file_dmitry["DYJ2"]
# old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"DYJ2 {year} sample comparison", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine["DYJ2"]
# up.Add(file_mine["DYJ2"])

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
hist2.Draw("HIST SAME")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 ", "l")
legend.AddEntry(hist3, f"Dmitry ", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  ", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
# canvas.SetTitle()
canvas.Draw()
# canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_2018.root"
my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_{year}.root"

process = "VV"
file_newmine = rt.TFile(my_newpath)
new = file_newmine[process]
# new.Add(file_newmine["DYJ2"])


# down = file_dmitry["data_obs"]
old_hist = file_dmitry[process]
# old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"{process} {year} sample comparison", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine[process]
# up.Add(file_mine["DYJ2"])

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
# hist2.Draw("HIST SAME")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 ", "l")
legend.AddEntry(hist3, f"Dmitry ", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  ", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
# canvas.SetTitle()
canvas.Draw()
# canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-sidebands_{year}.root"
# my_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SB.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul12/vbf_h-peak_2018.root"
# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jul31/vbf_h-peak_2018.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-peak_2018.root"
my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_dnn_allyears_128_64_32/vbf_h-sidebands_{year}.root"

process = "DYJ01"
file_newmine = rt.TFile(my_newpath)
new = file_newmine[process]
# new.Add(file_newmine["DYJ2"])


# down = file_dmitry["data_obs"]
old_hist = file_dmitry[process]
# old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", f"{process} {year} sample comparison", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        
down = new_hist


up = file_mine[process]
# up.Add(file_mine["DYJ2"])

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)
hist4.SetLineWidth(1)

# Draw the histograms on the canvas

# 
hist3.Draw("HIST")  # Overlay the third histogram
# hist2.Draw("HIST SAME")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"pytorch_jun27 ", "l")
legend.AddEntry(hist3, f"Dmitry ", "l")
legend.AddEntry(hist4, f"dnn_allyears_128_64_32  ", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
# canvas.SetTitle()
canvas.Draw()
# canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
import ROOT as rt
year = 2018
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SB.root"
file_dmitry = rt.TFile(official_path)

hist = file_dmitry["data_obs"]
n_bins = hist.GetNbinsX()
for i in range(1, n_bins + 2):
    bin_low_edge = hist.GetXaxis().GetBinLowEdge(i)
    print(bin_low_edge)
# Out:
# 0.0
# 0.07
# 0.432
# 0.71
# 0.926
# 1.114
# 1.28
# 1.428
# 1.564
# 1.686
# 1.798
# 1.9
# 2.0
# 2.8

# %%
# hist4.Integral()
# file_newmine["data_obs"].GetNbinsX()
file_newmine["data_obs"].Integral()
# Out:
# 3932.0

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

# my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
# file_newmine = rt.TFile(my_newpath)

old_hist = file_dmitry["DYJ01"]
old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
down = new_hist

up = file_mine["DYJ01"]
up.Add(file_mine["DYJ2"])
# new = file_newmine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
# hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
# hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)
# hist4.SetLineWidth(2)

# Draw the histograms on the canvas

hist2.Draw("HIST ")  # Overlay the second histogram
# hist4.Draw("HIST SAME")  # Overlay the second histogram
hist3.Draw("HIST SAME")  # Overlay the third histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"Hyeon-Seo DY {year}", "l")
legend.AddEntry(hist3, f"Dmitry DY {year}", "l")
# legend.AddEntry(hist4, f"Hyeon-Seo data Original {year}", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
canvas.Draw()
canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF comparision 2018.png has been created

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"
file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)

        

old_hist = file_dmitry["data_obs"]
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
down = new_hist

old_hist = file_dmitry["DYJ01"]
old_hist.Add(file_dmitry["DYJ2"])
new_edges = np.arange(14, dtype=np.double)
n_bins = len(new_edges) - 1
new_hist = rt.TH1F("newHist", "Histogram with Custom Bins", n_bins, new_edges)
for i in range(1, old_hist.GetNbinsX() + 1):
        bin_center = old_hist.GetBinCenter(i)
        bin_content = old_hist.GetBinContent(i)
        new_hist.SetBinContent(i, bin_content)
        # new_hist.Fill(bin_center, bin_content)
        
up = new_hist
# new = file_newmine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
# hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
# hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)
# hist4.SetLineWidth(2)

# Draw the histograms on the canvas

hist2.Draw("HIST ")  # Overlay the second histogram
# hist4.Draw("HIST SAME")  # Overlay the second histogram
hist3.Draw("HIST SAME")  # Overlay the third histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"Dmitry DY {year}", "l")
legend.AddEntry(hist3, f"Dmitry Data Obs {year}", "l")
# legend.AddEntry(hist4, f"Hyeon-Seo data Original {year}", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
canvas.Draw()
canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: newHist (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF comparision 2018.png has been created

# %%
import ROOT as rt
import numpy as np

year = "2018"
my_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Nov27_puidWgtOn/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

file_mine = rt.TFile(my_path)
official_path = f"/work/users/yun79/vbf_Run2dataCard/datacards/{year}_jul7_score_dnn_allyears_128_64_32/shapes_vbf_SR.root"
# official_path ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_dmitry = rt.TFile(official_path)


# my_newpath = f"/depot/cms/users/yun79/hmm/copperheadV1clean/rereco_yun_Dec02_puidWgtOn_JecOff/stage3_templates/score_pytorch_jun27/vbf_h-peak_{year}.root"

my_newpath ="/depot/cms/users/yun79/hmm/copperheadV1clean//rereco_yun_Dec02_puidWgtOn_OrigData/stage3_templates/score_pytorch_jun27/vbf_h-peak_2018.root"
file_newmine = rt.TFile(my_newpath)


down = file_mine["data_obs"]

up = file_mine["DYJ01"]
up.Add(file_mine["DYJ2"])
new = file_newmine["data_obs"]

# Create a canvas
canvas = rt.TCanvas("canvas", "Canvas VBF base", 800, 600)

# Create three TH1D histograms
hist2 = up
hist3 = down
hist4 = new


# Set histogram styles
hist2.SetLineColor(rt.kBlue)
hist3.SetLineColor(rt.kRed)
hist4.SetLineColor(rt.kGreen)
hist2.SetLineWidth(2)
hist3.SetLineWidth(2)
hist4.SetLineWidth(2)

# Draw the histograms on the canvas

hist2.Draw("HIST ")  # Overlay the second histogram
hist4.Draw("HIST SAME")  # Overlay the second histogram
hist3.Draw("HIST SAME")  # Overlay the third histogram

# Add a legend
legend = rt.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist2, f"Hyeon-Seo DY {year}", "l")
legend.AddEntry(hist3, f"Hyeon-Seo Data Obs {year}", "l")
legend.AddEntry(hist4, f"Hyeon-Seo data JEC off {year}", "l")
legend.Draw()

# Display the canvas
canvas.SetLogy()
canvas.Draw()
canvas.SaveAs(f"VBF comparision {year}.png")  # Save the canvas as an image if needed
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file VBF comparision 2018.png has been created
